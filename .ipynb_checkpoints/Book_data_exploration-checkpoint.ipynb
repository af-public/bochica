# %% [markdown]
# # Book data exploration
#
# I want to just run through the book archive and see if I can find some interesting word clouds.
#
# I think I should start by figuring out how to grab books in english first.
#
# It looks like that is in the metadata for each of the books.

# %% [markdown]
# ## Documentation here:
#
# https://docs.google.com/document/d/10cNGGYrDFu0BJg-pUYYzKpjB1TWkqKspTZl2YG-yLJ4/edit
#
# ## Important files at each identifier:
# - {item}_meta.txt - contains metadata for each item like language and author
# - {item}_djvu.txt - contains the raw text for the book

# %%
# Import libraries here:
import requests
from os import path
import xml.etree.ElementTree as ET
import re

# Workhorse data libraries
import pandas as pd
import numpy as np

# Wordcloud stuff
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

#viz and interactive buttons
import matplotlib.pyplot as plt
import ipywidgets as widgets
# %matplotlib inline

# %% [markdown]
# ## Read in the identifiers here
# - use the index in the repo to load a list of books in the library into memory.
#
# You can query books by id number like this:
#
# `df.loc[index, 0]` this returns a string with the text identifer

# %%
df = pd.read_csv("2017-12-26_public-domain-books-dataset_800k-identifiers.csv",header=None)

# %% [markdown]
# ## Dynamically create a url for each request
#
# We're making a URL for both the full text and the meta data

# %%
base_url = 'https://archive.org/download/{itemid}/{itemid}_'
query_id = 200000

full_txt_url = base_url.format(itemid=df.loc[query_id,0]) + "djvu.txt"
meta_txt_url = base_url.format(itemid=df.loc[query_id,0]) + "meta.xml"

# %%
full_txt_url
# Out:
# 'https://archive.org/download/descendantsofben00rice/descendantsofben00rice_djvu.txt'

# %% [markdown]
# ## Pull out interesting info (like title) from the metadata

# %%
r_meta = requests.get(meta_txt_url)
tree_meta = ET.fromstring(r_meta.content)

# %%
tree_meta[0].text
# Out:
# 'Descendants of Benjamin Rice'

# %% [markdown]
# ## Make a simple word cloud

# %%
r_text = requests.get(full_txt_url)

# %%
wc = WordCloud().generate(r_text.text)

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.title(tree_meta[0].text)
plt.show()

# %% [markdown]
# ## Make an interactive version using widgets

# %%
@widgets.interact(cloud_plotter, query_id=widgets.IntSlider(min=0, max=len(df), step=1, value=6900))
def cloud_plotter(query_id):
    """
    This function takes in an ID number, then prints everything out nice like
    """
    # Form URLs
    base_url = 'https://archive.org/download/{itemid}/{itemid}_'
    full_txt_url = base_url.format(itemid=df.loc[query_id,0]) + "djvu.txt"
    meta_txt_url = base_url.format(itemid=df.loc[query_id,0]) + "meta.xml"
    
    # Request metadata and full text
    r_meta = requests.get(meta_txt_url)
    r_text = requests.get(full_txt_url)
    
    # Parse metadata
    tree_meta = ET.fromstring(r_meta.content)
    
    # Plot wordcloud
    wc = WordCloud().generate(r_text.text)
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.title(tree_meta[0].text)
    plt.show()
# Out:
# interactive(children=(IntSlider(value=6900, description='query_id', max=869172), Output()), _dom_classes=('wid…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-13b41ae06d68> in <module>
# ----> 1 @widgets.interact(cloud_plotter, query_id=widgets.IntSlider(min=0, max=len(df), step=1, value=6900))
#       2 def cloud_plotter(query_id):
#       3     """
#       4     This function takes in an ID number, then prints everything out nice like
#       5     """
#
# <ipython-input-51-0d1a3c7d60e6> in cloud_plotter(query_id)
#       5     # Form URLs
#       6     base_url = 'https://archive.org/download/{itemid}/{itemid}_'
# ----> 7     full_txt_url = base_url.format(itemid=df.loc[query_id,0]) + "djvu.txt"
#       8     meta_txt_url = base_url.format(itemid=df.loc[query_id,0]) + "meta.xml"
#       9
#
# c:\conda_envs\snappy_36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     864     def __getitem__(self, key):
#     865         if type(key) is tuple:
# --> 866             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     867             if self._is_scalar_access(key):
#     868                 try:
#
# c:\conda_envs\snappy_36\lib\site-packages\pandas\core\indexing.py in <genexpr>(.0)
#     864     def __getitem__(self, key):
#     865         if type(key) is tuple:
# --> 866             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     867             if self._is_scalar_access(key):
#     868                 try:
#
# c:\conda_envs\snappy_36\lib\site-packages\pandas\core\common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     339     """
#     340     if callable(maybe_callable):
# --> 341         return maybe_callable(obj, **kwargs)
#     342
#     343     return maybe_callable
#
# <ipython-input-55-13b41ae06d68> in cloud_plotter(query_id)
#       6     # Form URLs
#       7     base_url = 'https://archive.org/download/{itemid}/{itemid}_'
# ----> 8     full_txt_url = base_url.format(itemid=df.loc[query_id,0]) + "djvu.txt"
#       9     meta_txt_url = base_url.format(itemid=df.loc[query_id,0]) + "meta.xml"
#      10
#
# c:\conda_envs\snappy_36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# c:\conda_envs\snappy_36\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# c:\conda_envs\snappy_36\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     808                     return section
#     809                 # This is an elided recursive call to iloc/loc
# --> 810                 return getattr(section, self.name)[new_key]
#     811
#     812         raise IndexingError("not applicable")
#
# c:\conda_envs\snappy_36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# c:\conda_envs\snappy_36\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1095
#    1096                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
#    1099                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
cloud_plotter(400000)
