# %% [markdown]
# # Metadata exploration
#
# We are exploring the metadata files that I pulled from the open library.

# %%
import pymongo
import xmltodict
from pathlib import Path
from tqdm import tqdm
import re

# %% [markdown]
# ## Get the path to the metadata files

# %%
p = Path("../meta/")

# %%
file_list = [x for x in p.glob("*.txt")]

# %%
len(file_list)
# Out:
# 869172

# %% [markdown]
# ## Start with a small slice of your files

# %%
# Define a function to read in your XML files
def xml_reader(fid):
    with open(fid, "rb") as f:
        my_dictionary = xmltodict.parse(f)
    
    return my_dictionary.get('metadata')

# %%
meta_data = []
file_limit = 1000

for i in tqdm(file_list[:file_limit], total=file_limit):
    meta_data.append(xml_reader(i))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 853.20it/s]

# %% [markdown]
# ## Clean the data for insertion into the database

# %%
# Data cleaning process
meta_dict = []
for x in meta_data:
    if x:
        meta_dict.append({k.replace('.', ''): v for k, v in x.items()})
    else:
        pass

# %%
meta_dict
# Out:
# [{'language': ['Ukrainian', 'English'],
#   'scanningcenter': 'alberta',
#   'sponsor': 'University of Alberta Libraries',
#   'contributor': 'Canadian Institute of Ukrainian Studies',
#   'date': '1993',
#   'subject': ['Ukrainian literature', 'Ukrainian literature'],
#   'title': 'Поза традиції: антологія модерної української поезії в діяспор',
#   'creator': ['Boychuk, Bohdan',
#    'Fizer, John',
#    'Makaryk, Irena R.',
#    'Struk, Danylo H'],
#   'isbn': '0920862888',
#   'collection': ['cius_books',
#    'ualberta_ukrainian_studies',
#    'university_of_alberta_libraries',
#    'toronto'],
#   'shiptracking': 'cius02',
#   'cat_key': '1622335',
#   'patron_notes': 'The anthology was inspired by a symposium on Ukrainian émigré poetry held at the University of Ottawa in 1985. Contributors include Vasyl Barka, Marta Kalytovska, Emma Andrijevska, Natalia Livytska-Kholoda, Marta Kalytovska, Vera Vovk, Yuri Tarnawsky, Boh',
#   'publisher': '[Edmonton] : Vyd-vo Kanadsʹkoho instytutu ukr. studiĭ, Alʹbertsʹkyĭ universytet',
#   'description': ['Added t.p. in English: Beyond tradition', '43'],
#   'mediatype': 'texts',
#   'repub_state': '4',
#   'page-progression': 'lr',
#   'publicdate': '2016-10-03 19:46:44',
#   'updatedate': '2016-10-03 20:45:30',
#   'updater': 'associate-aaron-campbell@archive.org',
#   'identifier': '00boyc_0',
#   'uploader': 'associate-aaron-campbell@archive.org',
#   'addeddate': '2016-10-03 20:45:32',
#   'scanner': 'scribe1.alberta.archive.org',
#   'repub_seconds': '2133',
#   'ppi': '500',
#   'camera': 'Canon EOS 5D Mark II',
#   'operator': 'associate-tanya-ulmer@archive.org',
#   'scandate': '20161013203113',
#   'republisher': 'associate-amy-alexander@archive.org',
#   'imagecount': '490',
#   'foldoutcount': '0',
#   'identifier-access': 'http://archive.org/details/00boyc_0',
#   'identifier-ark': 'ark:/13960/t0ht7k374',
#   'bookplateleaf': '0004',
#   'ocr': 'ABBYY FineReader 11.0 (Extended OCR)',
#   'scanfee': '120',
#   'invoice': '1',
#   'sponsordate': '20161130',
#   'backup_location': 'ia906208_3',
#   'openlibrary_edition': 'OL11445607M',
#   'openlibrary_work': 'OL3196992W',
#   'year': '1993',
#   'republisher_operator': 'associate-amy-alexander@archive.org',
#   'republisher_date': '20161014142009',
#   'external-identifier': 'urn:oclc:record:1037359179',
#   '_id': ObjectId('5fa1a22c8016ac27739bef8a')},
#  {'identifier': '00generalindexto00ontauoft',
#   'title': 'General index to the journals and sessional papers of the Legislative Assembly, Ontario, 1889-1900, 52 to 63 Vict., also, Index to the divisions in House and list of appendixes to journals, 1867-8 to 1900, 31 to 63 Vict.',
#   'creator': ['Ontario. Legislative Assembly',
#    'Sydere, Arthur H. (Arthur Henry), 1841-1926'],
#   'mediatype': 'texts',
#   'description': ['Bound with: Index to the debates and speeches in the Legislative Assembly of the province of Ontario',
#    '150492',
#    '45'],
#   'date': '1889-1900',
#   'year': '1889',
#   'subject': ['Ontario. Legislative Assembly',
#    'Legislative journals -- Ontario Indexes'],
#   'publicdate': '2007-07-26 18:56:04',
#   'addeddate': '2007-07-26 18:55:51',
#   'uploader': 'liz@archive.org',
#   'updater': ['scanner-liz-ridolfo', 'gabe@archive.org'],
#   'updatedate': ['2007-07-26 18:55:49', '2007-08-14 16:51:04'],
#   'contributor': 'Legislative Assembly of Ontario',
#   'publisher': 'Toronto : L.K. Cameron',
#   'language': 'eng',
#   'sponsor': 'Legislative Assembly of Ontario',
#   'scanningcenter': 'uoft',
#   'call_number': '10180297',
#   'repub_state': '4',
#   'imagecount': '266',
#   'ppi': '500',
#   'lcamid': '327166',
#   'rcamid': '331217',
#   'camera': '1Ds',
#   'operator': 'scanner-hari-alluri@archive.org',
#   'scanner': 'ias7',
#   'scandate': '20070727162042',
#   'identifier-access': 'http://www.archive.org/details/00generalindexto00ontauoft',
#   'identifier-ark': 'ark:/13960/t8df6ns8h',
#   'curation': '[curator]lajolla@archive.org[/curator][date]20070730203114[/date][state]approved[/state][comment]199[/comment]',
#   'possible-copyright-status': '&copy; Legislative Assembly of Ontario. May be reproduced for non-commercial purposes.',
#   'filesxml': 'Wed Mar 17 3:44:52 UTC 2010',
#   'collection': ['ontla', 'toronto', 'governmentpublications'],
#   'foldoutcount': '0',
#   'backup_location': 'ia903601_5',
#   'openlibrary_edition': 'OL7218428M',
#   'openlibrary_work': 'OL3156112W',
#   'external-identifier': 'urn:oclc:record:848444445',
#   '_id': ObjectId('5fa1a22c8016ac27739bef8b')},
#  {'language': 'Ukrainian',
#   'scanningcenter': 'alberta',
#   'sponsor': 'University of Alberta Libraries',
#   'contributor': 'Canadian Institute of Ukrainian Studies',
#   'date': '1983',
#   'subject': ['Folk songs, Ukrainian', 'Folklore'],
#   'title': 'Українська усна словесність',
#   'creator': 'Kolessa, Filiaret',
#   'isbn': '0920862233',
#   'collection': ['cius_books',
#    'ualberta_ukrainian_studies',
#    'university_of_alberta_libraries',
#    'toronto'],
#   'shiptracking': 'cius02',
#   'cat_key': '418261',
#   'patron_notes': 'This is a survey of Ukrainian folklore from the pre-Christian era to the mid-1930s.',
#   'publisher': 'Edmonton : Canadian Institute of Ukrainian Studies, University of Alberta',
#   'description': ['Title romanized',
#    'Reprint. Originally published: Lʹviv : Nakladom fondu "Uchitesi͡a, braty moï", 1938',
#    'Bibliography: p. (627)-630',
#    '38 43'],
#   'mediatype': 'texts',
#   'repub_state': '4',
#   'page-progression': 'lr',
#   'publicdate': '2016-10-03 19:46:45',
#   'updatedate': '2016-10-03 20:45:36',
#   'updater': 'associate-aaron-campbell@archive.org',
#   'identifier': '00kole_0',
#   'uploader': 'associate-aaron-campbell@archive.org',
#   'addeddate': '2016-10-03 20:45:38',
#   'scanner': 'scribe1.alberta.archive.org',
#   'repub_seconds': '177681',
#   'ppi': '500',
#   'camera': 'Canon EOS 5D Mark II',
#   'operator': 'associate-tanya-ulmer@archive.org',
#   'scandate': '20161014162313',
#   'republisher': 'associate-tanya-ulmer@archive.org',
#   'imagecount': '718',
#   'foldoutcount': '0',
#   'identifier-access': 'http://archive.org/details/00kole_0',
#   'identifier-ark': 'ark:/13960/t4xh4jr6b',
#   'bookplateleaf': '0002',
#   'ocr': 'ABBYY FineReader 11.0',
#   'scanfee': '120',
#   'invoice': '1',
#   'sponsordate': '20161130',
#   'backup_location': 'ia906208_3',
#   'openlibrary_edition': 'OL2802631M',
#   'openlibrary_work': 'OL5324681W',
#   'external-identifier': 'urn:oclc:record:1037355994',
#   '_id': ObjectId('5fa1a22c8016ac27739bef8c')},
#  {'language': 'Ukrainian',
#   'scanningcenter': 'alberta',
#   'sponsor': 'University of Alberta Libraries',
#   'contributor': 'Canadian Institute of Ukrainian Studies',
#   'date': '1970',
#   'subject': ['Kozub, Ivan', 'Political prisoners', 'Ukrainian Canadians'],
#   'title': 'Доба і доля: Спогади',
#   'creator': 'Kozub, Ivan',
#   'isbn': '1895571170',
#   'collection': ['cius_books',
#    'ualberta_ukrainian_studies',
#    'university_of_alberta_libraries',
#    'toronto'],
#   'shiptracking': 'cius02',
#   'cat_key': '2397503',
#   'patron_notes': "Contains recollections of peasant life, the Ukrainian Revolution, and the author's experiences as a prisioner in the GULAG.",
#   'publisher': 'Kyïv : TAKSON ; Edmonton : Kanadsʹkyĭ in-t ukr. studiĭ',
#   'description': ['"Literaturno-khudoz͡hni͡e vydanni͡a"--Colophon', '43'],
#   'mediatype': 'texts',
#   'repub_state': '4',
#   'page-progression': 'lr',
#   'publicdate': '2016-10-03 19:46:46',
#   'updatedate': '2016-10-03 20:45:40',
#   'updater': 'associate-aaron-campbell@archive.org',
#   'identifier': '00kozu_0',
#   'uploader': 'associate-aaron-campbell@archive.org',
#   'addeddate': '2016-10-03 20:45:42',
#   'scanner': 'scribe1.alberta.archive.org',
#   'repub_seconds': '1211',
#   'ppi': '500',
#   'camera': 'Canon EOS 5D Mark II',
#   'operator': 'associate-tanya-ulmer@archive.org',
#   'scandate': '20161014172437',
#   'republisher': 'associate-amy-alexander@archive.org',
#   'imagecount': '524',
#   'foldoutcount': '0',
#   'identifier-access': 'http://archive.org/details/00kozu_0',
#   'identifier-ark': 'ark:/13960/t6062h427',
#   'bookplateleaf': '0002',
#   'ocr': 'ABBYY FineReader 11.0',
#   'scanfee': '120',
#   'invoice': '1',
#   'sponsordate': '20161130',
#   'backup_location': 'ia906208_3',
#   'openlibrary_edition': 'OL12223095M',
#   'openlibrary_work': 'OL9866021W',
#   'external-identifier': 'urn:oclc:record:1037356841',
#   '_id': ObjectId('5fa1a22c8016ac27739bef8d')},
#  {'language': 'Ukrainian',
#   'scanningcenter': 'alberta',
#   'sponsor': 'University of Alberta Libraries',
#   'contributor': 'Canadian Institute of Ukrainian Studies',
#   'date': '1977',
#   'subject': ['Vaplite', 'Ukrainian literature'],
#   'title': 'Ваплітянський збірник',
#   'creator': 'Luckyj, George S.N.',
#   'isbn': '0889620504',
#   'collection': ['cius_books',
#    'ualberta_ukrainian_studies',
#    'university_of_alberta_libraries',
#    'toronto'],
#   'shiptracking': 'cius02',
#   'cat_key': '212966',
#   'patron_notes': 'This is a rich collection of letters, diaries, poetry, and fiction from the archives of VAPLITE (1925–28). Writers include M. Khvylovy, P. Tychyna, M. Kulish, M. Bazhan, V. Sosiura, A. Lubchenko, O. Vyshnia, and many others.',
#   'publisher': 'Oakville, Ont. : Mozaïka',
#   'description': ['Added t.p.: The VAPLITE collection',
#    '"Vydanni͡a Kanads\'koho instytutu ukraïns\'kykh studiĭ"',
#    'Text in Ukrainian; introd. in English',
#    'University of Alberta copy a gift of Richard Spafford',
#    '38'],
#   'mediatype': 'texts',
#   'repub_state': '4',
#   'page-progression': 'lr',
#   'publicdate': '2016-10-03 19:46:42',
#   'updatedate': '2016-10-03 20:45:22',
#   'updater': 'associate-aaron-campbell@archive.org',
#   'identifier': '00luck_0',
#   'uploader': 'associate-aaron-campbell@archive.org',
#   'addeddate': '2016-10-03 20:45:24',
#   'scanner': 'scribe1.alberta.archive.org',
#   'notes': 'no contents page',
#   'repub_seconds': '1037',
#   'ppi': '500',
#   'camera': 'Canon EOS 5D Mark II',
#   'operator': 'ekaitlyn@ualberta.ca',
#   'scandate': '20161011222046',
#   'republisher': 'associate-amy-alexander@archive.org',
#   'imagecount': '310',
#   'foldoutcount': '0',
#   'identifier-access': 'http://archive.org/details/00luck_0',
#   'identifier-ark': 'ark:/13960/t2n63gc05',
#   'bookplateleaf': '0008',
#   'ocr': 'ABBYY FineReader 11.0',
#   'scanfee': '120',
#   'invoice': '1',
#   'curation': '[curator]associate-denise-bentley@archive.org[/curator][date]20161107144032[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20161130',
#   'backup_location': 'ia906208_3',
#   'openlibrary_edition': 'OL22326648M',
#   'openlibrary_work': 'OL17374484W',
#   'external-identifier': 'urn:oclc:record:1037356092',
#   '_id': ObjectId('5fa1a22c8016ac27739bef8e')},
#  {'identifier': '00representmen00emerrich',
#   'call_number': 'ucb:GLAD-84064318',
#   'scanningcenter': 'rich',
#   'sponsor': 'MSN',
#   'mediatype': 'texts',
#   'contributor': 'University of California Libraries',
#   'updatedate': '2006-09-13 16:14:13',
#   'updater': 'scanner-ian-white',
#   'title': 'Representative men',
#   'creator': 'Emerson, Ralph Waldo, 1803-1882',
#   'date': '19--?',
#   'publisher': 'Philadelphia : H. ALtemus',
#   'language': 'eng',
#   'copyright-evidence-operator': 'scanner-ian-white',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'copyright-region': 'US',
#   'copyright-evidence': 'Evidence reported by scanner-ian-white for item 00representmen00emerrich on Sep 13, 2006; no visible notice of copyright and date found; exact publication date unknown; not published by the US government; a copyright renewal record could not be found.',
#   'copyright-evidence-date': '2006-09-13 16:14:54',
#   'imagecount': '342',
#   'ppi': '600',
#   'operator': 'scanner-adrian-wiemhoff@archive.org',
#   'scanner': 'rich4',
#   'scandate': '20060914040949',
#   'identifier-access': 'http://www.archive.org/details/00representmen00emerrich',
#   'identifier-ark': 'ark:/13960/t7br8n21p',
#   'collection-library': 'ucb',
#   'identifier-bib': 'GLAD-84064318',
#   'publicdate': '2006-09-14 04:19:32',
#   'curation': '[curator]julie@archive.org[/curator][date]20060928031520[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20060930',
#   'lcamid': '318500',
#   'rcamid': '319916',
#   'camera': '1Ds',
#   'filesxml': 'Wed Mar 17 3:44:52 UTC 2010',
#   'collection': ['cdl', 'americana'],
#   'foldoutcount': '0',
#   'repub_state': '4',
#   'backup_location': 'ia903600_21',
#   'openlibrary_edition': 'OL7067011M',
#   'openlibrary_work': 'OL62248W',
#   'external-identifier': 'urn:oclc:record:1037384918',
#   'addeddate': '2006-09-14 04:19:32',
#   '_id': ObjectId('5fa1a22c8016ac27739bef8f')},
#  {'language': 'Ukrainian',
#   'scanningcenter': 'alberta',
#   'sponsor': 'University of Alberta Libraries',
#   'contributor': 'Canadian Institute of Ukrainian Studies',
#   'date': '1990',
#   'subject': 'Ukrainian poetry',
#   'title': 'Вісімдесятники: антологія нової української поезії',
#   'creator': 'Rymaruk, Ihor',
#   'isbn': '0920862691',
#   'collection': ['cius_books',
#    'ualberta_ukrainian_studies',
#    'university_of_alberta_libraries',
#    'toronto'],
#   'shiptracking': 'cius02',
#   'cat_key': '1322005',
#   'patron_notes': 'Forty outstanding examples of the new wave in Ukrainian poetry of the 1980s. Includes writings by Yuri Andrukhovych, Natalka Bilotserkivets, Yuri Buriak, Stanislav Vyshensky, Mykola Vorobiov, Petro Halych, Vasyl Herasymiuk, Oksana Zabuzhko. Oleksander Irv',
#   'publisher': 'Edmonton : Vyd-vo Kanadsʹkoho instytutu ukraïnsʹkykh studiĭ, Albertsʹkyĭ universytet',
#   'description': ['Title on added t.p.: Poets of the eighties', '43'],
#   'mediatype': 'texts',
#   'repub_state': '4',
#   'page-progression': 'lr',
#   'publicdate': '2016-10-03 19:46:43',
#   'updatedate': '2016-10-03 20:45:26',
#   'updater': 'associate-aaron-campbell@archive.org',
#   'identifier': '00ryma_0',
#   'uploader': 'associate-aaron-campbell@archive.org',
#   'addeddate': '2016-10-03 20:45:28',
#   'scanner': 'scribe1.alberta.archive.org',
#   'repub_seconds': '678',
#   'ppi': '500',
#   'camera': 'Canon EOS 5D Mark II',
#   'operator': 'associate-tanya-ulmer@archive.org',
#   'scandate': '20161013170437',
#   'republisher': 'associate-amy-alexander@archive.org',
#   'imagecount': '230',
#   'foldoutcount': '0',
#   'identifier-access': 'http://archive.org/details/00ryma_0',
#   'identifier-ark': 'ark:/13960/t5m95558x',
#   'bookplateleaf': '0002',
#   'ocr': 'ABBYY FineReader 11.0',
#   'scanfee': '120',
#   'invoice': '1',
#   'curation': '[curator]associate-denise-bentley@archive.org[/curator][date]20161107154107[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20161130',
#   'backup_location': 'ia906208_3',
#   'openlibrary_edition': 'OL11445600M',
#   'openlibrary_work': 'OL9636674W',
#   'external-identifier': 'urn:oclc:record:1037356169',
#   '_id': ObjectId('5fa1a22c8016ac27739bef90')},
#  {'language': 'Ukrainian',
#   'scanningcenter': 'alberta',
#   'sponsor': 'University of Alberta Libraries',
#   'contributor': 'Canadian Institute of Ukrainian Studies',
#   'date': '1999',
#   'subject': ['Trylʹovsʹkyĭ, Kyrylo', 'Nationalists'],
#   'title': 'З мого життя',
#   'creator': 'Tryliovsky, Kyrylo',
#   'isbn': '1895571308',
#   'collection': ['cius_books',
#    'ualberta_ukrainian_studies',
#    'university_of_alberta_libraries',
#    'toronto'],
#   'shiptracking': 'cius02',
#   'cat_key': '2570608',
#   'patron_notes': 'З мого життя (From My Life) are the memoirs of Kyrylo Tryliovsky (1864–1941), remembered chiefly as the founder of the Sich Society in the Hutsul and Pokutia regions of western Ukraine, before the First World War.',
#   'publisher': 'Edmonton : Kanadsʹkyĭ in-t ukraïnsʹkykh studiĭ ; Kyïv : Vyd-vo TAKSON',
#   'description': ['"Literaturno-khudoz͡hni͡e vydanni͡a"--Colophon', '43'],
#   'mediatype': 'texts',
#   'repub_state': '4',
#   'page-progression': 'lr',
#   'publicdate': '2016-10-03 19:46:47',
#   'updatedate': '2016-10-03 20:45:51',
#   'updater': 'associate-aaron-campbell@archive.org',
#   'identifier': '00tryl_0',
#   'uploader': 'associate-aaron-campbell@archive.org',
#   'addeddate': '2016-10-03 20:45:54',
#   'scanner': 'scribe1.alberta.archive.org',
#   'notes': 'No table-of-contents pages found.',
#   'repub_seconds': '305',
#   'ppi': '500',
#   'camera': 'Canon EOS 5D Mark II',
#   'operator': 'associate-tanya-ulmer@archive.org',
#   'scandate': '20161013162415',
#   'republisher': 'associate-mark-turnbull@archive.org',
#   'imagecount': '304',
#   'foldoutcount': '0',
#   'identifier-access': 'http://archive.org/details/00tryl_0',
#   'identifier-ark': 'ark:/13960/t11p31f4k',
#   'bookplateleaf': '0003',
#   'ocr': 'ABBYY FineReader 11.0',
#   'scanfee': '120',
#   'invoice': '1',
#   'sponsordate': '20161130',
#   'backup_location': 'ia906208_3',
#   'openlibrary_edition': 'OL6872411M',
#   'openlibrary_work': 'OL7825234W',
#   'external-identifier': 'urn:oclc:record:1037391673',
#   '_id': ObjectId('5fa1a22c8016ac27739bef91')},
#  {'title': 'Catalogus der handschriften ..',
#   'volume': 'v.04 pt.01',
#   'creator': 'Amsterdam. Universiteit. Bibliotheek',
#   'subject': 'Manuscripts -- Bibliography',
#   'description': ['Schenking-Diederichs. Nederlandsche afdeeling. Bewerkt door J. Hellendoorn. 1899.- II. De handschriften der Stedelijke bibliotheek met de latere aanwinsten. Bewerkt door M.B. Mendes da Costa. Vooraf eenige mededeelingen over de geschiedenis van de bibliotheek en hare handschriftenverzameling, door den bibliothecaris C.P. Burger, jr. 1902.- III. Schenking-Diederichs. Fransche afdeeling. Bewerkt door J. Hollendoorn. 1903.- IV. Brieven. 1919.- V. Schenking-Diederichs. Kleinere afdeelingen (Engeland en Noord-American, Scandinavische landen, Rusland en Polen) Bewerkt door T.P. Sevensma. 1913.- VI. Schenking-Diederichs. Kleinere afdeelingen (Italië, Spanje, Portugal, Hongarije, Turkije, Griekenland, Indië, enz.) Bewerkt door Bertha M.v.d. Stempel. 1917.- VII. De handschriften, krachtens buikleencontract in de Universitetsbibliotheek berustende. 1e gedeelte: De handschriften van de Remonstrantsche kerk beschreven door M.B. Mendes da Costa. De handscriften van het Evangelisch-luthersche seminarium en van de Vereenigde Doopsgezinde gemeente, beschreven door J. Berg. 1923',
#    '26'],
#   'publisher': 'Amsterdam',
#   'date': '1899-1923',
#   'language': 'dut',
#   'sponsor': 'University of Toronto',
#   'contributor': 'Robarts - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['robarts', 'toronto'],
#   'call_number': 'AFE-3600',
#   'updatedate': '2008-11-11 15:23:36',
#   'updater': 'Marlete Kurten',
#   'identifier': '01catalogusderha04amstuoft',
#   'uploader': 'marlete@archive.org',
#   'addeddate': '2008-11-11 15:24:07',
#   'publicdate': '2008-11-11 15:24:13',
#   'ppi': '400',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'scanner-jake-keating@archive.org',
#   'scanner': 'scribe16.toronto.archive.org',
#   'missingpages': None,
#   'scandate': '20081112193309',
#   'imagecount': '292',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/01catalogusderha04amstuoft',
#   'identifier-ark': 'ark:/13960/t1gh9rv7p',
#   'scanfactors': '5',
#   'repub_state': '4',
#   'curation': '[curator]julie@archive.org[/curator][date]20081205012434[/date][state]approved[/state]',
#   'sponsordate': '20081130',
#   'backup_location': 'ia903602_19',
#   'openlibrary_edition': 'OL23262373M',
#   'openlibrary_work': 'OL1299493W',
#   'external-identifier': 'urn:oclc:record:1037385485',
#   '_id': ObjectId('5fa1a22c8016ac27739bef92')},
#  {'identifier': '01generalin00ontauoft',
#   'title': 'General index to the Journals and Sessional papers of the Legislative Assembly, Ontario, 1901 to 1912 : also index to the Divisions in House and lists of appendixes to journal for same period',
#   'creator': ['Ontario. Legislative Assembly',
#    'Ontario. Legislative Assembly. Sessional papers ... of the Province of Ontario',
#    'Ontario. Legislative Assembly. Journals of the Legislative Assembly of the Province of Ontario',
#    'Sydere, Arthur H. (Arthur Henry), 1841-1926'],
#   'mediatype': 'texts',
#   'description': '45',
#   'date': '1901-1912',
#   'year': '1901',
#   'subject': ['Legislative journals -- Ontario Indexes',
#    'Ontario -- Politics and government'],
#   'publicdate': '2007-07-26 18:54:26',
#   'addeddate': '2007-07-26 18:54:16',
#   'uploader': 'liz@archive.org',
#   'updater': ['scanner-liz-ridolfo', 'gabe@archive.org'],
#   'updatedate': ['2007-07-26 18:54:13', '2007-08-14 17:00:58'],
#   'contributor': 'Legislative Assembly of Ontario',
#   'publisher': 'Toronto : W. Briggs',
#   'language': 'eng',
#   'sponsor': 'Legislative Assembly of Ontario',
#   'scanningcenter': 'uoft',
#   'call_number': '000029806160',
#   'repub_state': '4',
#   'imagecount': '520',
#   'ppi': '500',
#   'lcamid': '327166',
#   'rcamid': '331217',
#   'camera': '1Ds',
#   'operator': 'scanner-hari-alluri@archive.org',
#   'scanner': 'ias7',
#   'scandate': '20070727172356',
#   'identifier-access': 'http://www.archive.org/details/01generalin00ontauoft',
#   'identifier-ark': 'ark:/13960/t8sb40m62',
#   'curatestate': 'approved',
#   'sponsordate': '20080531',
#   'possible-copyright-status': '&copy; Legislative Assembly of Ontario. May be reproduced for non-commercial purposes.',
#   'curation': '[curator]sharda@archive.org[/curator][date]20091125231546[/date][state]approved[/state]',
#   'filesxml': 'Wed Mar 17 3:44:52 UTC 2010',
#   'collection': ['ontla', 'toronto', 'governmentpublications'],
#   'foldoutcount': '0',
#   'backup_location': 'ia903601_5',
#   'openlibrary_edition': 'OL7043731M',
#   'openlibrary_work': 'OL3156143W',
#   'external-identifier': 'urn:oclc:record:1037380256',
#   '_id': ObjectId('5fa1a22c8016ac27739bef93')},
#  {'title': 'Hydrologic data, 1964',
#   'volume': 'no.130:64 v.2',
#   'creator': ['California. Dept. of Water Resources',
#    'Warne, William E',
#    'Mullnix, Lawrence A',
#    'Angel, Jacob',
#    'Werner, Carla'],
#   'subject': ['Hydrology', 'Water-supply'],
#   'description': ['7 folded maps (some col.), 1 folded chart inserted',
#    '"William E. Warne, Director, Department of Water Resources."',
#    '"This report was prepared ... by Carl A. Werner, Lawrence A. Mullnix, Jacob Angel"--P. ix',
#    '"May 1966."'],
#   'publisher': '[Sacramento, Calif.] : The Department',
#   'date': '1966',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'sponsor': 'Kahle/Austin Foundation and Omidyar Network',
#   'contributor': 'University of California Libraries',
#   'scanningcenter': 'rich',
#   'mediatype': 'texts',
#   'call_number': 'TC824.C2 A2 no.130:64 v.2',
#   'collection-library': 'ucd',
#   'identifier-bib': 'DVXL-002999036',
#   'updatedate': '2009-04-21 15:06:36',
#   'updater': 'sf-loaders@archive.org',
#   'identifier': '01hydrologicdata19130642calirich',
#   'uploader': 'sf-loaders@archive.org',
#   'addeddate': '2009-04-21 15:06:38',
#   'publicdate': '2009-04-21 15:06:48',
#   'ppi': '400',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'scanner-kevin-narine@archive.org',
#   'scanner': 'scribe3.rich.archive.org',
#   'missingpages': None,
#   'scandate': '20090424195812',
#   'imagecount': '448',
#   'foldoutcount': '9',
#   'identifier-access': 'http://www.archive.org/details/01hydrologicdata19130642calirich',
#   'identifier-ark': 'ark:/13960/t9k365j3j',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfactors': '7',
#   'repub_state': '4',
#   'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]',
#   'collection': ['cawaterres', 'ucdavis', 'americana'],
#   'backup_location': 'ia903603_0',
#   'openlibrary_edition': 'OL25391116M',
#   'openlibrary_work': 'OL16722313W',
#   'external-identifier': 'urn:oclc:record:1037399464',
#   '_id': ObjectId('5fa1a22c8016ac27739bef94')},
#  {'identifier': '01monprevwagenonconrich',
#   'title': 'Montana prevailing wage rates : nonconstruction services rates effective June 30, 2001',
#   'creator': 'Montana. Job Service Division',
#   'mediatype': 'texts',
#   'date': '2001',
#   'year': '2001',
#   'subject': ['Service industries workers', 'Wages'],
#   'publicdate': '2008-11-18 18:44:12',
#   'addeddate': '2008-11-18 18:44:01',
#   'uploader': 'markg@archive.org',
#   'updater': ['MarkGraves', 'Andy Wilcoxon'],
#   'updatedate': ['2008-11-18 18:43:58', '2009-06-24 21:15:55'],
#   'contributor': 'Montana State Library',
#   'publisher': 'Helena, MT : The Division',
#   'language': 'eng',
#   'sponsor': 'Montana State Library',
#   'scanningcenter': 'rich',
#   'identifier-bib': '30864001558595',
#   'ppi': '300',
#   'camera': 'Canon 5D',
#   'operator': 'scanner-francis-ong@archive.org',
#   'scanner': 'scribe8.rich.archive.org',
#   'scandate': '20081119150421',
#   'imagecount': '64',
#   'identifier-access': 'http://www.archive.org/details/01monprevwagenonconrich',
#   'identifier-ark': 'ark:/13960/t3rv0tr96',
#   'scanfactors': '3',
#   'curation': '[curator]markg@archive.org[/curator][date]20081121193149[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20081130',
#   'volume': '2001',
#   'collection': ['MontanaStateLibrary', 'americana'],
#   'call_number': '331.21',
#   'oclc-id': '47106465',
#   'biblevel': 'monograph',
#   'description': 'Cover title',
#   'foldoutcount': '0',
#   'repub_state': '4',
#   'backup_location': 'ia903602_19',
#   'openlibrary_edition': 'OL22796086M',
#   'openlibrary_work': 'OL13683703W',
#   'external-identifier': 'urn:oclc:record:1037395250',
#   '_id': ObjectId('5fa1a22c8016ac27739bef95')},
#  {'title': 'Philosophia militans : gegen Klerikalismus und Naturalismus',
#   'creator': 'Paulsen, Friedrich, 1846-1908',
#   'subject': ['Naturalism',
#    'Philosophy and religion',
#    'Philosophy, German',
#    'Philosophy, Modern'],
#   'description': '24',
#   'publisher': 'Berlin : Reuther & Reichard',
#   'date': '1901',
#   'language': 'ger',
#   'copyright-evidence-operator': 'andrea@archive.org',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'copyright-region': 'US',
#   'copyright-evidence': 'Evidence reported by andrea@archive.org for item 01philosophiamilit00pauluoft on June 12, 2008: no visible notice of copyright; stated date is 1901.',
#   'copyright-evidence-date': '20080612144232',
#   'sponsor': 'MSN',
#   'contributor': 'OISE - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['oiseut', 'toronto'],
#   'call_number': 'AXU-2235',
#   'repub_state': '-1',
#   'updatedate': '2008-06-12 14:42:36',
#   'updater': 'andrea@archive.org',
#   'identifier': '01philosophiamilit00pauluoft',
#   'uploader': 'andrea@archive.org',
#   'addeddate': '2008-06-12 14:42:38',
#   'publicdate': '2008-06-12 14:43:02',
#   'ppi': '500',
#   'lcamid': '342124',
#   'rcamid': '327166',
#   'camera': '1Ds',
#   'operator': 'scanner-terry-haryett@archive.org',
#   'scanner': 'iasw2',
#   'missingpages': None,
#   'scandate': '20080618155814',
#   'imagecount': '210',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/01philosophiamilit00pauluoft',
#   'identifier-ark': 'ark:/13960/t9m32xw3x',
#   'scanfactors': '0',
#   'curation': '[curator]sharda@archive.org[/curator][date]20080620000515[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20080630',
#   'backup_location': 'ia903602_2',
#   'openlibrary_edition': 'OL23262420M',
#   'openlibrary_work': 'OL1534544W',
#   'external-identifier': 'urn:oclc:record:697603602',
#   '_id': ObjectId('5fa1a22c8016ac27739bef96')},
#  {'title': 'Polybiblion; revue bibliographique universelle',
#   'volume': 'v.137 n.01',
#   'creator': 'Société bibliographique, Paris',
#   'subject': ['Bibliography -- Periodicals',
#    'Books -- Reviews',
#    'French literature -- Bibliography Periodicals'],
#   'description': ['Published by the Société bibliographique',
#    'Absorbed the Bulletin critique de littérature in 1909',
#    '26'],
#   'publisher': 'Paris',
#   'language': 'fre',
#   'sponsor': 'University of Toronto',
#   'contributor': 'Robarts - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['robarts', 'toronto'],
#   'call_number': 'ABC 8014',
#   'updatedate': '2008-10-09 20:36:44',
#   'updater': 'Marlete Kurten',
#   'identifier': '01polybiblionre137sociuoft',
#   'uploader': 'marlete@archive.org',
#   'addeddate': '2008-10-09 20:34:50',
#   'publicdate': '2008-10-09 20:34:58',
#   'ppi': '400',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'scanner-jake-keating@archive.org',
#   'scanner': 'scribe12.toronto.archive.org',
#   'missingpages': None,
#   'scandate': '20081014175837',
#   'imagecount': '92',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/01polybiblionre137sociuoft',
#   'identifier-ark': 'ark:/13960/t9m332r8k',
#   'scanfactors': '0',
#   'repub_state': '4',
#   'curation': '[curator]julie@archive.org[/curator][date]20081109[/date][state]approved[/state][comment][/comment]',
#   'sponsordate': '20081031',
#   'backup_location': 'ia903602_15',
#   'openlibrary_edition': 'OL19359040M',
#   'openlibrary_work': 'OL16891258W',
#   'external-identifier': 'urn:oclc:record:1037355469',
#   '_id': ObjectId('5fa1a22c8016ac27739bef97')},
#  {'title': 'Die Erdkunde im Verhältniss zur Natur und zur Geschichte des Menschen; oder, Allgemeine vergleichende Geographie als sichere Grundlage des Studiums und Unterrichts in physikalischen und historischen Wissenschaften',
#   'volume': '01 pt.02',
#   'creator': 'Ritter, Carl, 1779-1859',
#   'subject': ['Physical geography -- Asia', 'Asia -- Description and travel'],
#   'description': ['Vol. 1. Afrika.- Vol. 2. Der Norden und Nord-Osten von Hoch-Asien.- Vol. 3. Der Nord-Osten und der Süden von Hoch-Asien.- Vol. 4. Der Süd-Osten von Hoch-Asien; dessen Wassersysteme und Gliederungen gegen Osten und Süden.- Vol. 5-6. Die indische Welt.- Vol. 7. West-Asien. Uebergang von Ost- nach West-Asien.- Vol. 8-9. West-Asien. Iranische Welt.- Vol. 10-11. Das Stufenland des Euphrat- und Tigrissystems.- Vol. 12-13. Die Halbinsel Arabien. Namen- und Sach-Verzeichniss [v. 12-13] bearb. von G.Fr.H. Müller.- Vol. 14. Die Sinai-Halbinsel.- Vol. 15 pt. 1-2. Palästina und Syrien. Namen- und Sach-Verzeichniss [v. 14-15] bearb. von G.Fr.H. Müller.- Vol. 16 pt. 1. Palästina und Syrien: Judäa, Samaria, Galiläa.- Vol. 17. pt. 1-2. Syrien. 1. Phönicien, Libanon und gebirgiges Nord-Syrien. 2. Das Stromsystem des Orontes und das flache Nord-Syrien mit der Amanuskette. Namen- und Sach-Verzeichniss [v. 16-17] bearb. von G.Fr.H. Müller.- Vol. 18-19. Klein-Asien',
#    '26'],
#   'publisher': 'Berlin, G. Reimer',
#   'date': '1822-1849',
#   'language': 'ger',
#   'sponsor': 'University of Toronto',
#   'contributor': 'Robarts - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['robarts', 'toronto'],
#   'call_number': 'AEX-7085',
#   'updatedate': '2008-11-14 21:55:43',
#   'updater': 'Marlete Kurten',
#   'identifier': '02dieerdkundeimver15rittuoft',
#   'uploader': 'marlete@archive.org',
#   'addeddate': '2008-11-14 21:56:15',
#   'publicdate': '2008-11-14 21:56:22',
#   'ppi': '400',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'scanner-bruce-milne@archive.org',
#   'scanner': 'scribe14.toronto.archive.org',
#   'missingpages': None,
#   'scandate': '20081117221411',
#   'imagecount': '748',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/02dieerdkundeimver15rittuoft',
#   'identifier-ark': 'ark:/13960/t6154vp5q',
#   'scanfactors': '1',
#   'repub_state': '4',
#   'curation': '[curator]sharda@archive.org[/curator][date]20081129000608[/date][state]approved[/state]',
#   'sponsordate': '20081130',
#   'backup_location': 'ia903602_19',
#   'openlibrary_edition': 'OL23262444M',
#   'openlibrary_work': 'OL3705262W',
#   'external-identifier': 'urn:oclc:record:1037355995',
#   '_id': ObjectId('5fa1a22c8016ac27739bef98')},
#  {'title': 'A history of Greece;',
#   'volume': '4 pt. 2',
#   'creator': 'Duruy, Victor, 1811-1894',
#   'description': '45 52',
#   'publisher': 'London, Paul',
#   'date': '1892',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'sponsor': 'University of Toronto',
#   'contributor': 'Robarts - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['robarts', 'toronto'],
#   'call_number': 'AEN-9686',
#   'repub_state': '4',
#   'updatedate': '2011-01-10 21:38:35',
#   'updater': 'Kate Farnworth',
#   'identifier': '02historyofgree04duru',
#   'uploader': 'scanner-kate-farnworth@archive.org',
#   'addeddate': '2011-01-10 21:38:37',
#   'publicdate': '2011-01-10 21:38:40',
#   'scanner': 'scribe23.toronto.archive.org',
#   'ppi': '300',
#   'camera': 'Canon 5D',
#   'operator': 'scanner-m-turnbull@archive.org',
#   'scandate': '20110111193051',
#   'imagecount': '314',
#   'foldoutcount': '2',
#   'identifier-access': 'http://www.archive.org/details/02historyofgree04duru',
#   'identifier-ark': 'ark:/13960/t46q2s68t',
#   'bookplateleaf': '0002',
#   'ocr': 'ABBYY FineReader 8.0',
#   'curation': '[curator]sharda@archive.org[/curator][date]20110203190403[/date][state]approved[/state]',
#   'sponsordate': '20110131',
#   'scanfee': '105',
#   'backup_location': 'ia903608_12',
#   'openlibrary_edition': 'OL24773151M',
#   'openlibrary_work': 'OL15864488W',
#   'external-identifier': 'urn:oclc:record:698288050',
#   '_id': ObjectId('5fa1a22c8016ac27739bef99')},
#  {'title': 'Hydrologic data, 1964. Appendix C: Ground water measurements',
#   'volume': 'no.130:64 v.2 Appx. C',
#   'creator': ['California. Dept. of Water Resources', 'Warne, William E'],
#   'subject': ['Hydrology', 'Water-supply', 'Groundwater'],
#   'description': ['10 folded maps in pocket',
#    '"September 1965."',
#    '"William E. Warne, Director, Department of Water Resources."'],
#   'publisher': '[Sacramento, Calif.] : The Department',
#   'date': '1965',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'sponsor': 'Kahle/Austin Foundation and Omidyar Network',
#   'contributor': 'University of California Libraries',
#   'scanningcenter': 'rich',
#   'mediatype': 'texts',
#   'call_number': 'TC824.C2 A2 no.130:64 v.2 Appx. C',
#   'collection-library': 'ucd',
#   'identifier-bib': 'DVXL-002999037',
#   'updatedate': '2009-04-21 15:09:17',
#   'updater': 'sf-loaders@archive.org',
#   'identifier': '02hydrologicdata19130642calirich',
#   'uploader': 'sf-loaders@archive.org',
#   'addeddate': '2009-04-21 15:09:19',
#   'publicdate': '2009-04-21 15:09:30',
#   'ppi': '400',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'scanner-sokpheap-meas@archive.org',
#   'scanner': 'scribe9.rich.archive.org',
#   'missingpages': None,
#   'scandate': '20090423184438',
#   'imagecount': '232',
#   'foldoutcount': '11',
#   'identifier-access': 'http://www.archive.org/details/02hydrologicdata19130642calirich',
#   'identifier-ark': 'ark:/13960/t59c7b05z',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfactors': '7',
#   'repub_state': '4',
#   'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]',
#   'collection': ['cawaterres', 'ucdavis', 'americana'],
#   'backup_location': 'ia903603_0',
#   'openlibrary_edition': 'OL23335196M',
#   'openlibrary_work': 'OL5337985W',
#   'external-identifier': 'urn:oclc:record:1037357646',
#   '_id': ObjectId('5fa1a22c8016ac27739bef9a')},
#  {'identifier': '02lastmohicans00cooprich',
#   'uploader': 'scanner-ian-white@archive.org',
#   'addeddate': '2006-09-12 23:44:42',
#   'title': 'The last of the Mohicans : a narrative of 1757',
#   'creator': ['Cooper, James Fenimore, 1789-1851',
#    'Darley, Felix Octavius Carr, 1822-1888'],
#   'subject': ['Mohegan Indians',
#    'United States -- History French and Indian War, 1755-1763 Fiction'],
#   'date': '1902?',
#   'publisher': 'New York : D. Appleton',
#   'language': 'eng',
#   'copyright-evidence-operator': 'scanner-ian-white',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'copyright-region': 'US',
#   'copyright-evidence': 'Evidence reported by scanner-ian-white for item 02lastmohicans00cooprich on Sep 12, 2006; no visible notice of copyright and date found; exact publication date unknown; not published by the US government; a copyright renewal record could not be found.',
#   'copyright-evidence-date': '2006-09-12 23:47:15',
#   'copyright-comment': None,
#   'call_number': 'ucb:GLAD-84237627',
#   'scanningcenter': 'rich',
#   'sponsor': 'MSN',
#   'mediatype': 'texts',
#   'contributor': 'University of California Libraries',
#   'updatedate': '2006-09-12 23:44:45',
#   'updater': 'scanner-ian-white',
#   'imagecount': '462',
#   'ppi': '500',
#   'operator': 'scanner-andy-wilcoxon@archive.org',
#   'scanner': 'rich1',
#   'scandate': '20060913203955',
#   'identifier-access': 'http://www.archive.org/details/02lastmohicans00cooprich',
#   'identifier-ark': 'ark:/13960/t51g0j97b',
#   'collection-library': 'ucb',
#   'identifier-bib': 'GLAD-84237627',
#   'publicdate': '2006-09-14 01:52:14',
#   'curation': '[curator]julie@archive.org[/curator][date]20060922033412[/date][state]approved[/state]',
#   'sponsordate': '20060930',
#   'lcamid': '332127',
#   'rcamid': '332513',
#   'camera': '1Ds',
#   'filesxml': 'Wed Mar 17 3:44:52 UTC 2010',
#   'collection': ['cdl', 'americana'],
#   'foldoutcount': '0',
#   'repub_state': '4',
#   'backup_location': 'ia903600_21',
#   'openlibrary_edition': 'OL7091179M',
#   'openlibrary_work': 'OL77958W',
#   'external-identifier': 'urn:oclc:record:1037355148',
#   '_id': ObjectId('5fa1a22c8016ac27739bef9b')},
#  {'title': '0 2.°',
#   'creator': 'Freitas, Jordão Apollinario de',
#   'subject': 'Santarem, Manuel Francisco de Barros, Visconde de, 1791-1856',
#   'description': ['Includes bibliographical references', '52'],
#   'publisher': 'Lisboa : Officina typographica',
#   'date': '1909',
#   'language': 'por',
#   'page-progression': 'lr',
#   'sponsor': 'University of Toronto',
#   'contributor': 'Robarts - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['robarts', 'toronto'],
#   'call_number': 'ADT-5290',
#   'repub_state': '4',
#   'updatedate': '2010-12-07 16:36:31',
#   'updater': 'lexw@archive.org',
#   'identifier': '02viscondedesant00frei',
#   'uploader': 'lexw@archive.org',
#   'addeddate': '2010-12-07 16:36:33',
#   'publicdate': '2010-12-07 16:36:38',
#   'scanner': 'scribe22.toronto.archive.org',
#   'ppi': '500',
#   'camera': 'Canon 5D',
#   'operator': 'scanner-gabriel-areay@archive.org',
#   'scandate': '20101209012215',
#   'imagecount': '220',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/02viscondedesant00frei',
#   'identifier-ark': 'ark:/13960/t9t15t434',
#   'bookplateleaf': '0002',
#   'ocr': 'ABBYY FineReader 8.0',
#   'curation': '[curator]sharda@archive.org[/curator][date]20101210205314[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20101231',
#   'backup_location': 'ia903607_26',
#   'openlibrary_edition': 'OL24518541M',
#   'openlibrary_work': 'OL15566031W',
#   'external-identifier': 'urn:oclc:record:1037380004'},
#  {'title': 'Annual report',
#   'volume': '1903-04',
#   'creator': 'Chicago Historical Society',
#   'description': '26',
#   'publisher': 'Chicago',
#   'date': '1902-20',
#   'language': 'eng',
#   'copyright-evidence-operator': 'liz ridolfo',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'copyright-region': 'US',
#   'copyright-evidence': 'Evidence reported by liz ridolfo for item 0304annualreport00chicuoft on February 28, 2008: no visible notice of copyright; stated date is 1903.',
#   'copyright-evidence-date': '20080228235252',
#   'sponsor': 'MSN',
#   'contributor': 'Robarts - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['robarts', 'toronto'],
#   'call_number': 'AHE-1796',
#   'updatedate': '2008-02-28 23:52:59',
#   'updater': 'liz ridolfo',
#   'identifier': '0304annualreport00chicuoft',
#   'uploader': 'liz@archive.org',
#   'addeddate': '2008-02-28 23:49:51',
#   'publicdate': '2008-02-28 23:53:05',
#   'imagecount': '72',
#   'ppi': '400',
#   'camera': 'Canon 5D',
#   'operator': 'michaelg@archive.org',
#   'scanner': 'scribe21',
#   'scandate': '20080229031803',
#   'identifier-access': 'http://www.archive.org/details/0304annualreport00chicuoft',
#   'identifier-ark': 'ark:/13960/t4dn44t8z',
#   'bookplateleaf': '0004',
#   'lcamid': None,
#   'rcamid': None,
#   'missingpages': None,
#   'foldoutcount': '0',
#   'curation': '[curator]julie@archive.org[/curator][date]20080319152038[/date][state]approved[/state]',
#   'sponsordate': '20080229',
#   'filesxml': ['Mon Aug 17 21:09:47 UTC 2009',
#    'Fri Aug 28 2:20:32 UTC 2015',
#    'Fri Aug 28 2:27:29 UTC 2015'],
#   'ocr': 'ABBYY FineReader 8.0',
#   'repub_state': '4',
#   'backup_location': 'ia903601_25',
#   'openlibrary_edition': 'OL22796100M',
#   'openlibrary_work': 'OL13134271W',
#   'external-identifier': 'urn:oclc:record:848313051'},
#  {'title': 'Chosn pulgyo tongsa',
#   'volume': '3',
#   'creator': 'Yi, Nng-hwa, 1865-1945',
#   'subject': 'Buddhism',
#   'description': ['Text in Hanmun (Chinese characters)', '11'],
#   'publisher': 'Kynsng-pu : Sinmungwan,[1918]',
#   'date': '1918',
#   'language': 'kor',
#   'possible-copyright-status': 'Permission Granted to Digitize Item',
#   'sponsor': 'University of Toronto',
#   'contributor': 'Cheng Yu Tung East Asian Library - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['chengyutung', 'toronto'],
#   'call_number': 'ALY-2670',
#   'updatedate': '2009-02-17 18:50:16',
#   'updater': 'KatieLawson',
#   'identifier': '03chosnpulgyotongs8800uoft',
#   'uploader': 'katie@archive.org',
#   'addeddate': '2009-02-17 18:50:19',
#   'publicdate': '2009-02-17 18:50:23',
#   'ppi': '500',
#   'lcamid': '319253',
#   'rcamid': '330983',
#   'camera': '1Ds',
#   'operator': 'scanner-alicia-pryce@archive.org',
#   'scanner': 'iasw7.toronto.archive.org',
#   'missingpages': None,
#   'scandate': '20090224225010',
#   'imagecount': '1278',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/03chosnpulgyotongs8800uoft',
#   'identifier-ark': 'ark:/13960/t6nz8hd2k',
#   'ocr': 'ABBYY FineReader 9.0',
#   'repub_state': '4',
#   'curation': '[curator]sharda@archive.org[/curator][date]20090304200925[/date][state]approved[/state]',
#   'sponsordate': '20090228',
#   'page-progression': 'rl',
#   'backup_location': 'ia903602_28',
#   'openlibrary_edition': 'OL23262456M',
#   'openlibrary_work': 'OL13786627W',
#   'external-identifier': 'urn:oclc:record:1037380550'},
#  {'title': 'Hydrologic data, 1964. Appendix D: Surface water quality : Appendix E: Ground water quality',
#   'volume': 'no.130:64 v.2 Appx. D-E',
#   'creator': ['California. Dept. of Water Resources', 'Warne, William E'],
#   'subject': ['Hydrology', 'Water-supply', 'Groundwater'],
#   'description': ['"June 1966."',
#    '"William E. Warne, Director, Department of Water Resources."'],
#   'publisher': '[Sacramento, Calif.] : The Department',
#   'date': '1966',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'sponsor': 'Kahle/Austin Foundation and Omidyar Network',
#   'contributor': 'University of California Libraries',
#   'scanningcenter': 'rich',
#   'mediatype': 'texts',
#   'call_number': 'TC824.C2 A2 no.130:64 v.2 Appx. D-E',
#   'collection-library': 'ucd',
#   'identifier-bib': 'DVXL-002999038',
#   'updatedate': '2009-04-21 15:10:30',
#   'updater': 'sf-loaders@archive.org',
#   'identifier': '03hydrologicdata19130642calirich',
#   'uploader': 'sf-loaders@archive.org',
#   'addeddate': '2009-04-21 15:10:32',
#   'publicdate': '2009-04-21 15:10:42',
#   'ppi': '300',
#   'lcamid': '315160',
#   'rcamid': '324758',
#   'camera': '1Ds',
#   'operator': 'scanner-jennifer-mansfield@archive.org',
#   'scanner': 'richw1.rich.archive.org',
#   'missingpages': None,
#   'scandate': '20090423185522',
#   'imagecount': '248',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/03hydrologicdata19130642calirich',
#   'identifier-ark': 'ark:/13960/t75t4104d',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfactors': '0',
#   'repub_state': '4',
#   'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]',
#   'collection': ['cawaterres', 'ucdavis', 'americana'],
#   'backup_location': 'ia903603_0',
#   'openlibrary_edition': 'OL23335197M',
#   'openlibrary_work': 'OL5337985W',
#   'external-identifier': 'urn:oclc:record:1037356842'},
#  {'identifier': '04representmen00emerrich',
#   'call_number': 'ucb:GLAD-84064315',
#   'scanningcenter': 'rich',
#   'sponsor': 'MSN',
#   'mediatype': 'texts',
#   'contributor': 'University of California Libraries',
#   'updatedate': '2006-09-13 16:15:55',
#   'updater': 'scanner-ian-white',
#   'title': 'Representative men',
#   'creator': 'Emerson, Ralph Waldo, 1803-1882',
#   'date': '1904',
#   'publisher': 'London, J.M. Dent',
#   'language': 'eng',
#   'copyright-evidence-operator': 'scanner-ian-white',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'copyright-region': 'US',
#   'copyright-evidence': 'Evidence reported by scanner-ian-white for item 04representmen00emerrich on Sep 13, 2006; no visible notice of copyright and date found; stated date is 1904; not published by the US government; Have not checked for notice of renewal in the Copyright renewal records.',
#   'copyright-evidence-date': '2006-09-13 16:16:35',
#   'imagecount': '256',
#   'ppi': '600',
#   'operator': 'scanner-adrian-wiemhoff@archive.org',
#   'scanner': 'rich4',
#   'scandate': '20060914063712',
#   'identifier-access': 'http://www.archive.org/details/04representmen00emerrich',
#   'identifier-ark': 'ark:/13960/t6b27q792',
#   'collection-library': 'ucb',
#   'identifier-bib': 'GLAD-84064315',
#   'publicdate': '2006-09-14 04:31:00',
#   'curation': '[curator]julie@archive.org[/curator][date]20061006020944[/date][state]approved[/state]',
#   'sponsordate': '20060930',
#   'lcamid': '318500',
#   'rcamid': '319916',
#   'camera': '1Ds',
#   'filesxml': 'Wed Mar 17 3:44:52 UTC 2010',
#   'collection': ['cdl', 'americana'],
#   'foldoutcount': '0',
#   'repub_state': '4',
#   'backup_location': 'ia903600_21',
#   'openlibrary_edition': 'OL7229334M',
#   'openlibrary_work': 'OL62248W',
#   'external-identifier': 'urn:oclc:record:1037397093',
#   'addeddate': '2006-09-14 04:31:00'},
#  {'title': 'Hydrologic data, 1964',
#   'volume': 'no.130:64 v.3',
#   'creator': ['California. Dept. of Water Resources',
#    'Warne, William E',
#    'Peterson, Glenn R'],
#   'subject': ['Hydrology', 'Water-supply'],
#   'description': ['5 folded maps inserted',
#    '"June 1966."',
#    '"William E. Warne, Director, Department of Water Resources."',
#    '"Activities covered by this report were under the supervision of Glenn R. Peterson"--P. ix',
#    'Includes appendixes'],
#   'publisher': '[Sacramento, Calif.] : The Department',
#   'date': '1966',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'sponsor': 'Kahle/Austin Foundation and Omidyar Network',
#   'contributor': 'University of California Libraries',
#   'scanningcenter': 'rich',
#   'mediatype': 'texts',
#   'call_number': 'TC824.C2 A2 no.130:64 v.3',
#   'collection-library': 'ucd',
#   'identifier-bib': 'DVXL-002999039',
#   'updatedate': '2009-04-21 15:12:06',
#   'updater': 'sf-loaders@archive.org',
#   'identifier': '04ydrologicdata19130643calirich',
#   'uploader': 'sf-loaders@archive.org',
#   'addeddate': '2009-04-21 15:12:08',
#   'publicdate': '2009-04-21 15:12:11',
#   'ppi': '400',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'scanner-kevin-narine@archive.org',
#   'scanner': 'scribe3.rich.archive.org',
#   'missingpages': None,
#   'scandate': '20090423201240',
#   'imagecount': '272',
#   'foldoutcount': '13',
#   'identifier-access': 'http://www.archive.org/details/04ydrologicdata19130643calirich',
#   'identifier-ark': 'ark:/13960/t3dz0mr5q',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfactors': '6',
#   'repub_state': '4',
#   'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]',
#   'collection': ['cawaterres', 'ucdavis', 'americana'],
#   'backup_location': 'ia903603_0',
#   'openlibrary_edition': 'OL23335198M',
#   'openlibrary_work': 'OL5337985W',
#   'external-identifier': 'urn:oclc:record:1037356127'},
#  {'title': 'Hydrologic data, 1964',
#   'volume': 'no.130:64 v.4',
#   'creator': ['California. Dept. of Water Resources',
#    'Warne, William E',
#    'McIntyre, Victor B',
#    'Chastain, Cledith L'],
#   'subject': ['Hydrology', 'Water-supply'],
#   'description': ['"Activities covered by this report were under the supervision of Cledith L. Chastain, Victor B. McIntyre"--P. xi',
#    'Includes appendixes',
#    '2 folded maps in pocket',
#    '"December 1965."',
# ...
#   'mediatype': 'texts',
#   'collection': ['robarts', 'toronto'],
#   'call_number': '04035323',
#   'repub_state': '-1',
#   'updatedate': '2008-07-16 17:53:21',
#   'updater': 'KatieLawson',
#   'identifier': '1904johnbunyan00whituoft',
#   'uploader': 'katie@archive.org',
#   'addeddate': '2008-07-16 17:53:23',
#   'publicdate': '2008-07-16 17:53:28',
#   'ppi': '500',
#   'lcamid': '319253',
#   'rcamid': '331217',
#   'camera': '1Ds',
#   'operator': 'scanner-alicia-pryce@archive.org',
#   'scanner': 'iasw7.toronto.archive.org',
#   'missingpages': None,
#   'scandate': '20080725222738',
#   'imagecount': '274',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/1904johnbunyan00whituoft',
#   'identifier-ark': 'ark:/13960/t7sn0bk81',
#   'scanfactors': '0',
#   'curation': '[curator]sharda@archive.org[/curator][date]20080729030844[/date][state]approved[/state]',
#   'backup_location': 'ia903602_6',
#   'openlibrary_edition': 'OL23263438M',
#   'openlibrary_work': 'OL6667453W',
#   'external-identifier': 'urn:oclc:record:1037461251'},
#  {'title': "Morang's modern phonic primer",
#   'volume': '1',
#   'creator': 'Dearness, John, b. 1852',
#   'subject': 'Reading',
#   'description': ['Part 2 by John Dearness and Sidney Silcox',
#    'Title pages of part 2 missing'],
#   'publisher': 'Toronto : Morang & Co.',
#   'date': '1904',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'sponsor': 'Ontario Council of University Libraries and Member Libraries',
#   'contributor': 'The University of Western Ontario, Western Archives',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['universitywesterno', 'toronto'],
#   'call_number': 'LT1001.421.5.M645 1904',
#   'updatedate': '2009-05-29 18:40:17',
#   'updater': 'KatieLawson',
#   'identifier': '1904morangsmoder01dearuoft',
#   'uploader': 'katie@archive.org',
#   'addeddate': '2009-05-29 18:40:19',
#   'publicdate': '2009-05-29 18:40:51',
#   'ppi': '400',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'scanner-carrie-lounsbury@archive.org',
#   'scanner': 'scribe12.toronto.archive.org',
#   'missingpages': None,
#   'scandate': '20090529221126',
#   'imagecount': '72',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/1904morangsmoder01dearuoft',
#   'identifier-ark': 'ark:/13960/t4jm2pd2f',
#   'ocr': 'ABBYY FineReader 8.0',
#   'repub_state': '4',
#   'sponsordate': '20090531',
#   'curation': '[curator]andrea@archive.org[/curator][date]20091204200209[/date][state]approved[/state]',
#   'backup_location': 'ia903603_6',
#   'openlibrary_edition': 'OL23335255M',
#   'openlibrary_work': 'OL16724659W',
#   'external-identifier': 'urn:oclc:record:676748185'},
#  {'title': 'Niagara in summer and winter',
#   'creator': 'Jordan, J. Murray',
#   'description': ['The dates for each issue have been estimated',
#    "Stamp on back inside paper cover of 1905 issue: For sale only at Tugby's 5c. and 10c. Store Niagara Falls, N. Y",
#    'Inscription on back inside paper cover of 1905 issue: Decoration Day, 1905 from Ada'],
#   'publisher': '[Philadelphia, PA] : [J. Murray Jordan]',
#   'date': '[19--?]-',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'sponsor': 'Brock University',
#   'contributor': 'Brock University',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'call_number': 'B1181695',
#   'updatedate': '2009-03-17 21:38:49',
#   'updater': 'liz ridolfo',
#   'identifier': '1904niagarainsum00jorduoft',
#   'uploader': 'liz@archive.org',
#   'addeddate': '2009-03-17 21:38:51',
#   'publicdate': '2009-03-17 21:38:56',
#   'ppi': '300',
#   'lcamid': '330983',
#   'rcamid': '318502',
#   'camera': '1Ds',
#   'operator': 'scanner-gabriel-areay@archive.org',
#   'scanner': 'iasw3.toronto.archive.org',
#   'missingpages': None,
#   'scandate': '20090330235656',
#   'imagecount': '72',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/1904niagarainsum00jorduoft',
#   'identifier-ark': 'ark:/13960/t9h42359w',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfactors': '0',
#   'repub_state': '4',
#   'curation': '[curator]sharda@archive.org[/curator][date]20090331171619[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20090331',
#   'collection': ['BrockUniversity', 'toronto'],
#   'filesxml': 'Fri Aug 28 2:31:42 UTC 2015',
#   'backup_location': 'ia903602_32',
#   'openlibrary_edition': 'OL25533732M',
#   'openlibrary_work': 'OL16914859W',
#   'external-identifier': 'urn:oclc:record:1037453446'},
#  {'title': 'Bulletin',
#   'creator': ['Literary and Historical Society of Quebec',
#    'Literary and Historical Society of Quebec. Library bulletin'],
#   'subject': 'Québec (Province) -- History Societies, etc',
#   'description': ['Title varies: 1906, Library bulletin', '26'],
#   'publisher': '[Quebec]',
#   'language': 'eng',
#   'copyright-evidence-operator': 'andrea@archive.org',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'copyright-region': 'US',
#   'copyright-evidence': 'Evidence reported by andrea@archive.org for item 1904quebechist00liteuoft on May 24, 2007: no visible notice of copyright; stated date is 1904.',
#   'copyright-evidence-date': '20070524183130',
#   'sponsor': 'MSN',
#   'contributor': 'Robarts - University of Toronto',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'collection': ['robarts', 'toronto'],
#   'call_number': 'AAU-3676',
#   'identifier-access': 'http://www.archive.org/details/1904quebechist00liteuoft',
#   'updatedate': '2007-05-24 18:31:54',
#   'updater': 'andrea@archive.org',
#   'identifier': '1904quebechist00liteuoft',
#   'uploader': 'andrea@archive.org',
#   'addeddate': '2007-05-24 18:31:56',
#   'publicdate': '2007-05-24 18:31:59',
#   'imagecount': '100',
#   'ppi': '500',
#   'lcamid': '330983',
#   'rcamid': '332493',
#   'camera': '1Ds',
#   'operator': 'scanner-lisa-munroe@archive.org',
#   'scanner': 'ias2',
#   'scandate': '20070526000322',
#   'identifier-ark': 'ark:/13960/t4qj7b054',
#   'bookplateleaf': '0003',
#   'curation': '[curator]marcus@archive.org[/curator][date]20070608180014[/date][state]approved[/state]',
#   'sponsordate': '20070531',
#   'filesxml': 'Wed Mar 17 3:47:46 UTC 2010',
#   'foldoutcount': '0',
#   'ocr': 'ABBYY FineReader 8.0',
#   'repub_state': '4',
#   'backup_location': 'ia903601_1',
#   'openlibrary_edition': 'OL13988434M',
#   'openlibrary_work': 'OL17774140W',
#   'external-identifier': 'urn:oclc:record:1037447955'},
#  {'title': '... 1904 supplement to 1903 catalogue : new, rare and beautiful plants and seeds',
#   'volume': '1904',
#   'creator': ['Theodosia B. Shepherd Company',
#    'Henry G. Gilbert Nursery and Seed Trade Catalog Collection'],
#   'subject': ['Seed industry and trade Catalogs',
#    'Seeds Catalogs',
#    'Flowers Seeds Catalogs',
#    'Plants, Ornamental Catalogs',
#    'Nurseries (Horticulture) Catalogs'],
#   'description': 'Cover title',
#   'publisher': 'Ventura-by-the-Sea, Calif. : Theodosia B. Shepherd Co.',
#   'date': '1904',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'sponsor': 'U.S. Department of Agriculture, National Agricultural Library',
#   'contributor': 'U.S. Department of Agriculture, National Agricultural Library',
#   'scanningcenter': 'beltsville',
#   'mediatype': 'texts',
#   'collection': ['usda-nurseryandseedcatalog',
#    'usdanationalagriculturallibrary',
#    'fedlink',
#    'americana',
#    'biodiversity'],
#   'shiptracking': 'SC0005a',
#   'call_number': 'CAT31116265',
#   'identifier-bib': 'CAT31116265',
#   'series': 'Henry G. Gilbert Nursery and Seed Trade Catalog Collection',
#   'unique_id': 'CAT31116265',
#   'nal_call_number': '62.09',
#   'repub_state': '4',
#   'updatedate': '2013-04-15 15:32:10',
#   'updater': 'associate-adrianna-flores',
#   'identifier': '1904supplementto1904theo',
#   'uploader': 'associate-adrianna-flores@archive.org',
#   'addeddate': '2013-04-15 15:32:12',
#   'publicdate': '2013-04-15 15:32:15',
#   'repub_seconds': '432790',
#   'ppi': '500',
#   'camera': 'Canon EOS 5D Mark II',
#   'operator': 'associate-kellen-goodwin@archive.org',
#   'scanner': 'scribe3.beltsville.archive.org',
#   'scandate': '20130417134601',
#   'republisher': 'associate-kellen-goodwin@archive.org',
#   'imagecount': '24',
#   'foldoutcount': '0',
#   'identifier-access': 'http://archive.org/details/1904supplementto1904theo',
#   'identifier-ark': 'ark:/13960/t8md0h39m',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfee': '250',
#   'curation': '[curator]associate-caitlin-markey@archive.org[/curator][date]20130429161238[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20130430',
#   'rights': 'The contributing institution believes that this item is not in copyright.',
#   'backup_location': 'ia905609_14',
#   'openlibrary_edition': 'OL25518714M',
#   'openlibrary_work': 'OL16898265W',
#   'external-identifier': 'urn:oclc:record:1037433922'},
#  {'title': "1905-'06 descriptive catalogue of rare flowers : seeds, plants, bulbs, cacti, etc",
#   'volume': '1906',
#   'creator': ['Theodosia B. Shepherd Company',
#    'Henry G. Gilbert Nursery and Seed Trade Catalog Collection'],
#   'subject': ['Seed industry and trade Catalogs',
#    'Seeds Catalogs',
#    'Flowers Seeds Catalogs',
#    'Plants, Ornamental Catalogs',
#    'Nurseries (Horticulture) Catalogs',
#    'Cactus Seeds Catalogs'],
#   'description': ['Cover title', 'Includes index'],
#   'publisher': 'Ventura-by-the-Sea, Calif. : Theodosia B. Shepherd Co.',
#   'date': '1906',
#   'language': 'eng',
#   'page-progression': 'lr',
#   'sponsor': 'U.S. Department of Agriculture, National Agricultural Library',
#   'contributor': 'U.S. Department of Agriculture, National Agricultural Library',
#   'scanningcenter': 'beltsville',
#   'mediatype': 'texts',
#   'collection': ['usda-nurseryandseedcatalog',
#    'usdanationalagriculturallibrary',
#    'fedlink',
#    'americana',
#    'biodiversity'],
#   'shiptracking': 'NC0005c',
#   'call_number': 'CAT31116262',
#   'identifier-bib': 'CAT31116262',
#   'series': 'Henry G. Gilbert Nursery and Seed Trade Catalog Collection',
#   'unique_id': 'CAT31116262',
#   'nal_call_number': '62.09',
#   'repub_state': '4',
#   'updatedate': '2013-04-15 19:40:13',
#   'updater': 'associate-adrianna-flores',
#   'identifier': '190506descriptiv1906theo',
#   'uploader': 'associate-adrianna-flores@archive.org',
#   'addeddate': '2013-04-15 19:40:15',
#   'publicdate': '2013-04-15 19:40:19',
#   'scanner': 'scribe3.beltsville.archive.org',
#   'notes': 'No table-of-contents pages found. No copyright page found.',
#   'repub_seconds': '618',
#   'ppi': '500',
#   'camera': 'Canon EOS 5D Mark II',
#   'operator': 'associate-kellen-goodwin@archive.org',
#   'scandate': '20130501132453',
#   'republisher': 'associate-adrianna-flores@archive.org',
#   'imagecount': '78',
#   'foldoutcount': '0',
#   'identifier-access': 'http://archive.org/details/190506descriptiv1906theo',
#   'identifier-ark': 'ark:/13960/t4pk1zk5z',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfee': '150',
#   'curation': '[curator]associate-manuel-dennis@archive.org[/curator][date]20130514155428[/date][state]approved[/state][comment]199[/comment]',
#   'sponsordate': '20130531',
#   'rights': 'The contributing institution believes that this item is not in copyright.',
#   'backup_location': 'ia905609_15',
#   'openlibrary_edition': 'OL25522337M',
#   'openlibrary_work': 'OL16902370W',
#   'external-identifier': 'urn:oclc:record:1037460669'},
#  {'identifier': '1905biennialreportof1906montrich',
#   'title': 'Biennial report of the State Board of Land Commissioners of the state of Montana to the ... Legislative Assembly',
#   'creator': 'Montana. State Board of Land Commissioners',
#   'mediatype': 'texts',
#   'date': '1900',
#   'year': '1900',
#   'subject': 'Public lands',
#   'publicdate': '2009-03-05 15:08:56',
#   'addeddate': '2009-03-05 15:08:52',
#   'uploader': 'markg@archive.org',
#   'updater': ['MarkGraves', 'paul nguyen'],
#   'updatedate': ['2009-03-05 15:08:50', '2009-06-30 22:32:10'],
#   'contributor': 'Montana State Library',
#   'publisher': 'Helena, Mont. : State Pub. Co.',
#   'language': 'eng',
#   'sponsor': 'Montana State Library',
#   'scanningcenter': 'rich',
#   'identifier-bib': '30864100483984',
#   'ppi': '400',
#   'camera': 'Canon 5D',
#   'operator': 'andyw@archive.org',
#   'scanner': 'scribe5.rich.archive.org',
#   'scandate': '20090326155147',
#   'imagecount': '54',
#   'foldoutcount': '8',
#   'identifier-access': 'http://www.archive.org/details/1905biennialreportof1906montrich',
#   'identifier-ark': 'ark:/13960/t1vd7634c',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfactors': '2',
#   'repub_state': '4',
#   'curation': '[curator]naruta@archive.org[/curator][date]20090406190846[/date][state]approved[/state]',
#   'sponsordate': '20090331',
#   'volume': '1905-06',
#   'collection': ['MontanaStateLibrary', 'americana'],
#   'call_number': '333.1/09786',
#   'oclc-id': '32591916',
#   'biblevel': 'serial',
#   'backup_location': 'ia903602_30',
#   'openlibrary_edition': 'OL25589919M',
#   'openlibrary_work': 'OL17018164W',
#   'external-identifier': 'urn:oclc:record:875124861'},
#  {'title': "Cutter's guide to Niagara Falls, and adjacent points of interest. --",
#   'creator': 'Cutter, Charles, 1837-1912',
#   'publisher': '[Niagara Falls, N. Y.] : Charles Cutter',
#   'date': '1905',
#   'language': 'eng',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'sponsor': 'Brock University',
#   'contributor': 'Brock University',
#   'scanningcenter': 'uoft',
#   'mediatype': 'texts',
#   'call_number': 'B1023135',
#   'updatedate': '2009-03-17 01:04:42',
#   'updater': 'liz ridolfo',
#   'identifier': '1905cuttersguide00cuttuoft',
#   'uploader': 'liz@archive.org',
#   'addeddate': '2009-03-17 01:04:45',
#   'publicdate': '2009-03-17 01:04:48',
#   'ppi': '300',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'scanner-patrick-stitt@archive.org',
#   'scanner': 'scribe11.toronto.archive.org',
#   'missingpages': None,
#   'scandate': '20090317231052',
#   'imagecount': '96',
#   'foldoutcount': '0',
#   'identifier-access': 'http://www.archive.org/details/1905cuttersguide00cuttuoft',
#   'identifier-ark': 'ark:/13960/t7mp5cx93',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfactors': '1',
#   'repub_state': '4',
#   'curation': '[curator]naruta@archive.org[/curator][date]20090416172045[/date][state]approved[/state]',
#   'sponsordate': '20090331',
#   'collection': ['BrockUniversity', 'toronto'],
#   'filesxml': 'Fri Aug 28 2:31:43 UTC 2015',
#   'backup_location': 'ia903602_32',
#   'openlibrary_edition': 'OL23263443M',
#   'openlibrary_work': 'OL11727641W',
#   'external-identifier': 'urn:oclc:record:1037422247'},
#  {'title': '[Bulletin] showing by counties the mineral productions of California for the year 1905',
#   'volume': 'no.42',
#   'creator': ['Yale, Charles G', 'California State Mining Bureau'],
#   'subject': 'Mines and mineral resources',
#   'publisher': '[Sacramento? : s.n.',
#   'date': '1906',
#   'language': 'eng',
#   'possible-copyright-status': 'NOT_IN_COPYRIGHT',
#   'sponsor': 'Kahle/Austin Foundation and Omidyar Network',
#   'contributor': 'University of California Libraries',
#   'scanningcenter': 'rich',
#   'mediatype': 'texts',
#   'call_number': 'TN24.C3 A3 no.42',
#   'updatedate': '2008-11-25 23:28:14',
#   'updater': 'ian frederick-rothwell',
#   'identifier': '1905etinshowingb00yalerich',
#   'uploader': 'ianf-r@archive.org',
#   'addeddate': '2008-11-25 23:28:16',
#   'publicdate': '2008-11-25 23:28:24',
#   'ppi': '300',
#   'lcamid': None,
#   'rcamid': None,
#   'camera': 'Canon 5D',
#   'operator': 'andyw@archive.org',
#   'scanner': 'scribe10.rich.archive.org',
#   'missingpages': None,
#   'scandate': '20081209193740',
#   'imagecount': '12',
#   'foldoutcount': '4',
#   'identifier-access': 'http://www.archive.org/details/1905etinshowingb00yalerich',
#   'identifier-ark': 'ark:/13960/t2794fs4r',
#   'ocr': 'ABBYY FineReader 8.0',
#   'scanfactors': '1',
#   'repub_state': '4',
#   'curation': '[curator]markg@archive.org[/curator][date]20081217190150[/date][state]approved[/state][comment]199[/comment]',
#   'collection_library': 'ucd',
#   'collection-library': 'ucd',
#   'collection': ['caminesgeo', 'ucdavis', 'americana'],
#   'backup_location': 'ia903602_20',
#   'openlibrary_edition': 'OL22803895M',
#   'openlibrary_work': 'OL16724663W',
#   'external-identifier': 'urn:oclc:record:1037461228'}]

# %% [markdown]
# ## Set up the database

# %%
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
database = mongo_client['open_library']
collection = database['meta_data_info']

# %%
collection.drop()

# %%
collection.insert_many(meta_dict)

# %%
q = collection.find({''})

for x in q:
    print(x)
# Out:
# {'_id': ObjectId('5fa1a22c8016ac27739bef8a'), 'language': ['Ukrainian', 'English'], 'scanningcenter': 'alberta', 'sponsor': 'University of Alberta Libraries', 'contributor': 'Canadian Institute of Ukrainian Studies', 'date': '1993', 'subject': ['Ukrainian literature', 'Ukrainian literature'], 'title': 'Поза традиції: антологія модерної української поезії в діяспор', 'creator': ['Boychuk, Bohdan', 'Fizer, John', 'Makaryk, Irena R.', 'Struk, Danylo H'], 'isbn': '0920862888', 'collection': ['cius_books', 'ualberta_ukrainian_studies', 'university_of_alberta_libraries', 'toronto'], 'shiptracking': 'cius02', 'cat_key': '1622335', 'patron_notes': 'The anthology was inspired by a symposium on Ukrainian émigré poetry held at the University of Ottawa in 1985. Contributors include Vasyl Barka, Marta Kalytovska, Emma Andrijevska, Natalia Livytska-Kholoda, Marta Kalytovska, Vera Vovk, Yuri Tarnawsky, Boh', 'publisher': '[Edmonton] : Vyd-vo Kanadsʹkoho instytutu ukr. studiĭ, Alʹbertsʹkyĭ universytet', 'description': ['Added t.p. in English: Beyond tradition', '43'], 'mediatype': 'texts', 'repub_state': '4', 'page-progression': 'lr', 'publicdate': '2016-10-03 19:46:44', 'updatedate': '2016-10-03 20:45:30', 'updater': 'associate-aaron-campbell@archive.org', 'identifier': '00boyc_0', 'uploader': 'associate-aaron-campbell@archive.org', 'addeddate': '2016-10-03 20:45:32', 'scanner': 'scribe1.alberta.archive.org', 'repub_seconds': '2133', 'ppi': '500', 'camera': 'Canon EOS 5D Mark II', 'operator': 'associate-tanya-ulmer@archive.org', 'scandate': '20161013203113', 'republisher': 'associate-amy-alexander@archive.org', 'imagecount': '490', 'foldoutcount': '0', 'identifier-access': 'http://archive.org/details/00boyc_0', 'identifier-ark': 'ark:/13960/t0ht7k374', 'bookplateleaf': '0004', 'ocr': 'ABBYY FineReader 11.0 (Extended OCR)', 'scanfee': '120', 'invoice': '1', 'sponsordate': '20161130', 'backup_location': 'ia906208_3', 'openlibrary_edition': 'OL11445607M', 'openlibrary_work': 'OL3196992W', 'year': '1993', 'republisher_operator': 'associate-amy-alexander@archive.org', 'republisher_date': '20161014142009', 'external-identifier': 'urn:oclc:record:1037359179'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef8b'), 'identifier': '00generalindexto00ontauoft', 'title': 'General index to the journals and sessional papers of the Legislative Assembly, Ontario, 1889-1900, 52 to 63 Vict., also, Index to the divisions in House and list of appendixes to journals, 1867-8 to 1900, 31 to 63 Vict.', 'creator': ['Ontario. Legislative Assembly', 'Sydere, Arthur H. (Arthur Henry), 1841-1926'], 'mediatype': 'texts', 'description': ['Bound with: Index to the debates and speeches in the Legislative Assembly of the province of Ontario', '150492', '45'], 'date': '1889-1900', 'year': '1889', 'subject': ['Ontario. Legislative Assembly', 'Legislative journals -- Ontario Indexes'], 'publicdate': '2007-07-26 18:56:04', 'addeddate': '2007-07-26 18:55:51', 'uploader': 'liz@archive.org', 'updater': ['scanner-liz-ridolfo', 'gabe@archive.org'], 'updatedate': ['2007-07-26 18:55:49', '2007-08-14 16:51:04'], 'contributor': 'Legislative Assembly of Ontario', 'publisher': 'Toronto : L.K. Cameron', 'language': 'eng', 'sponsor': 'Legislative Assembly of Ontario', 'scanningcenter': 'uoft', 'call_number': '10180297', 'repub_state': '4', 'imagecount': '266', 'ppi': '500', 'lcamid': '327166', 'rcamid': '331217', 'camera': '1Ds', 'operator': 'scanner-hari-alluri@archive.org', 'scanner': 'ias7', 'scandate': '20070727162042', 'identifier-access': 'http://www.archive.org/details/00generalindexto00ontauoft', 'identifier-ark': 'ark:/13960/t8df6ns8h', 'curation': '[curator]lajolla@archive.org[/curator][date]20070730203114[/date][state]approved[/state][comment]199[/comment]', 'possible-copyright-status': '&copy; Legislative Assembly of Ontario. May be reproduced for non-commercial purposes.', 'filesxml': 'Wed Mar 17 3:44:52 UTC 2010', 'collection': ['ontla', 'toronto', 'governmentpublications'], 'foldoutcount': '0', 'backup_location': 'ia903601_5', 'openlibrary_edition': 'OL7218428M', 'openlibrary_work': 'OL3156112W', 'external-identifier': 'urn:oclc:record:848444445'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef8c'), 'language': 'Ukrainian', 'scanningcenter': 'alberta', 'sponsor': 'University of Alberta Libraries', 'contributor': 'Canadian Institute of Ukrainian Studies', 'date': '1983', 'subject': ['Folk songs, Ukrainian', 'Folklore'], 'title': 'Українська усна словесність', 'creator': 'Kolessa, Filiaret', 'isbn': '0920862233', 'collection': ['cius_books', 'ualberta_ukrainian_studies', 'university_of_alberta_libraries', 'toronto'], 'shiptracking': 'cius02', 'cat_key': '418261', 'patron_notes': 'This is a survey of Ukrainian folklore from the pre-Christian era to the mid-1930s.', 'publisher': 'Edmonton : Canadian Institute of Ukrainian Studies, University of Alberta', 'description': ['Title romanized', 'Reprint. Originally published: Lʹviv : Nakladom fondu "Uchitesi͡a, braty moï", 1938', 'Bibliography: p. (627)-630', '38 43'], 'mediatype': 'texts', 'repub_state': '4', 'page-progression': 'lr', 'publicdate': '2016-10-03 19:46:45', 'updatedate': '2016-10-03 20:45:36', 'updater': 'associate-aaron-campbell@archive.org', 'identifier': '00kole_0', 'uploader': 'associate-aaron-campbell@archive.org', 'addeddate': '2016-10-03 20:45:38', 'scanner': 'scribe1.alberta.archive.org', 'repub_seconds': '177681', 'ppi': '500', 'camera': 'Canon EOS 5D Mark II', 'operator': 'associate-tanya-ulmer@archive.org', 'scandate': '20161014162313', 'republisher': 'associate-tanya-ulmer@archive.org', 'imagecount': '718', 'foldoutcount': '0', 'identifier-access': 'http://archive.org/details/00kole_0', 'identifier-ark': 'ark:/13960/t4xh4jr6b', 'bookplateleaf': '0002', 'ocr': 'ABBYY FineReader 11.0', 'scanfee': '120', 'invoice': '1', 'sponsordate': '20161130', 'backup_location': 'ia906208_3', 'openlibrary_edition': 'OL2802631M', 'openlibrary_work': 'OL5324681W', 'external-identifier': 'urn:oclc:record:1037355994'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef8d'), 'language': 'Ukrainian', 'scanningcenter': 'alberta', 'sponsor': 'University of Alberta Libraries', 'contributor': 'Canadian Institute of Ukrainian Studies', 'date': '1970', 'subject': ['Kozub, Ivan', 'Political prisoners', 'Ukrainian Canadians'], 'title': 'Доба і доля: Спогади', 'creator': 'Kozub, Ivan', 'isbn': '1895571170', 'collection': ['cius_books', 'ualberta_ukrainian_studies', 'university_of_alberta_libraries', 'toronto'], 'shiptracking': 'cius02', 'cat_key': '2397503', 'patron_notes': "Contains recollections of peasant life, the Ukrainian Revolution, and the author's experiences as a prisioner in the GULAG.", 'publisher': 'Kyïv : TAKSON ; Edmonton : Kanadsʹkyĭ in-t ukr. studiĭ', 'description': ['"Literaturno-khudoz͡hni͡e vydanni͡a"--Colophon', '43'], 'mediatype': 'texts', 'repub_state': '4', 'page-progression': 'lr', 'publicdate': '2016-10-03 19:46:46', 'updatedate': '2016-10-03 20:45:40', 'updater': 'associate-aaron-campbell@archive.org', 'identifier': '00kozu_0', 'uploader': 'associate-aaron-campbell@archive.org', 'addeddate': '2016-10-03 20:45:42', 'scanner': 'scribe1.alberta.archive.org', 'repub_seconds': '1211', 'ppi': '500', 'camera': 'Canon EOS 5D Mark II', 'operator': 'associate-tanya-ulmer@archive.org', 'scandate': '20161014172437', 'republisher': 'associate-amy-alexander@archive.org', 'imagecount': '524', 'foldoutcount': '0', 'identifier-access': 'http://archive.org/details/00kozu_0', 'identifier-ark': 'ark:/13960/t6062h427', 'bookplateleaf': '0002', 'ocr': 'ABBYY FineReader 11.0', 'scanfee': '120', 'invoice': '1', 'sponsordate': '20161130', 'backup_location': 'ia906208_3', 'openlibrary_edition': 'OL12223095M', 'openlibrary_work': 'OL9866021W', 'external-identifier': 'urn:oclc:record:1037356841'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef8e'), 'language': 'Ukrainian', 'scanningcenter': 'alberta', 'sponsor': 'University of Alberta Libraries', 'contributor': 'Canadian Institute of Ukrainian Studies', 'date': '1977', 'subject': ['Vaplite', 'Ukrainian literature'], 'title': 'Ваплітянський збірник', 'creator': 'Luckyj, George S.N.', 'isbn': '0889620504', 'collection': ['cius_books', 'ualberta_ukrainian_studies', 'university_of_alberta_libraries', 'toronto'], 'shiptracking': 'cius02', 'cat_key': '212966', 'patron_notes': 'This is a rich collection of letters, diaries, poetry, and fiction from the archives of VAPLITE (1925–28). Writers include M. Khvylovy, P. Tychyna, M. Kulish, M. Bazhan, V. Sosiura, A. Lubchenko, O. Vyshnia, and many others.', 'publisher': 'Oakville, Ont. : Mozaïka', 'description': ['Added t.p.: The VAPLITE collection', '"Vydanni͡a Kanads\'koho instytutu ukraïns\'kykh studiĭ"', 'Text in Ukrainian; introd. in English', 'University of Alberta copy a gift of Richard Spafford', '38'], 'mediatype': 'texts', 'repub_state': '4', 'page-progression': 'lr', 'publicdate': '2016-10-03 19:46:42', 'updatedate': '2016-10-03 20:45:22', 'updater': 'associate-aaron-campbell@archive.org', 'identifier': '00luck_0', 'uploader': 'associate-aaron-campbell@archive.org', 'addeddate': '2016-10-03 20:45:24', 'scanner': 'scribe1.alberta.archive.org', 'notes': 'no contents page', 'repub_seconds': '1037', 'ppi': '500', 'camera': 'Canon EOS 5D Mark II', 'operator': 'ekaitlyn@ualberta.ca', 'scandate': '20161011222046', 'republisher': 'associate-amy-alexander@archive.org', 'imagecount': '310', 'foldoutcount': '0', 'identifier-access': 'http://archive.org/details/00luck_0', 'identifier-ark': 'ark:/13960/t2n63gc05', 'bookplateleaf': '0008', 'ocr': 'ABBYY FineReader 11.0', 'scanfee': '120', 'invoice': '1', 'curation': '[curator]associate-denise-bentley@archive.org[/curator][date]20161107144032[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20161130', 'backup_location': 'ia906208_3', 'openlibrary_edition': 'OL22326648M', 'openlibrary_work': 'OL17374484W', 'external-identifier': 'urn:oclc:record:1037356092'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef8f'), 'identifier': '00representmen00emerrich', 'call_number': 'ucb:GLAD-84064318', 'scanningcenter': 'rich', 'sponsor': 'MSN', 'mediatype': 'texts', 'contributor': 'University of California Libraries', 'updatedate': '2006-09-13 16:14:13', 'updater': 'scanner-ian-white', 'title': 'Representative men', 'creator': 'Emerson, Ralph Waldo, 1803-1882', 'date': '19--?', 'publisher': 'Philadelphia : H. ALtemus', 'language': 'eng', 'copyright-evidence-operator': 'scanner-ian-white', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'copyright-region': 'US', 'copyright-evidence': 'Evidence reported by scanner-ian-white for item 00representmen00emerrich on Sep 13, 2006; no visible notice of copyright and date found; exact publication date unknown; not published by the US government; a copyright renewal record could not be found.', 'copyright-evidence-date': '2006-09-13 16:14:54', 'imagecount': '342', 'ppi': '600', 'operator': 'scanner-adrian-wiemhoff@archive.org', 'scanner': 'rich4', 'scandate': '20060914040949', 'identifier-access': 'http://www.archive.org/details/00representmen00emerrich', 'identifier-ark': 'ark:/13960/t7br8n21p', 'collection-library': 'ucb', 'identifier-bib': 'GLAD-84064318', 'publicdate': '2006-09-14 04:19:32', 'curation': '[curator]julie@archive.org[/curator][date]20060928031520[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20060930', 'lcamid': '318500', 'rcamid': '319916', 'camera': '1Ds', 'filesxml': 'Wed Mar 17 3:44:52 UTC 2010', 'collection': ['cdl', 'americana'], 'foldoutcount': '0', 'repub_state': '4', 'backup_location': 'ia903600_21', 'openlibrary_edition': 'OL7067011M', 'openlibrary_work': 'OL62248W', 'external-identifier': 'urn:oclc:record:1037384918', 'addeddate': '2006-09-14 04:19:32'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef90'), 'language': 'Ukrainian', 'scanningcenter': 'alberta', 'sponsor': 'University of Alberta Libraries', 'contributor': 'Canadian Institute of Ukrainian Studies', 'date': '1990', 'subject': 'Ukrainian poetry', 'title': 'Вісімдесятники: антологія нової української поезії', 'creator': 'Rymaruk, Ihor', 'isbn': '0920862691', 'collection': ['cius_books', 'ualberta_ukrainian_studies', 'university_of_alberta_libraries', 'toronto'], 'shiptracking': 'cius02', 'cat_key': '1322005', 'patron_notes': 'Forty outstanding examples of the new wave in Ukrainian poetry of the 1980s. Includes writings by Yuri Andrukhovych, Natalka Bilotserkivets, Yuri Buriak, Stanislav Vyshensky, Mykola Vorobiov, Petro Halych, Vasyl Herasymiuk, Oksana Zabuzhko. Oleksander Irv', 'publisher': 'Edmonton : Vyd-vo Kanadsʹkoho instytutu ukraïnsʹkykh studiĭ, Albertsʹkyĭ universytet', 'description': ['Title on added t.p.: Poets of the eighties', '43'], 'mediatype': 'texts', 'repub_state': '4', 'page-progression': 'lr', 'publicdate': '2016-10-03 19:46:43', 'updatedate': '2016-10-03 20:45:26', 'updater': 'associate-aaron-campbell@archive.org', 'identifier': '00ryma_0', 'uploader': 'associate-aaron-campbell@archive.org', 'addeddate': '2016-10-03 20:45:28', 'scanner': 'scribe1.alberta.archive.org', 'repub_seconds': '678', 'ppi': '500', 'camera': 'Canon EOS 5D Mark II', 'operator': 'associate-tanya-ulmer@archive.org', 'scandate': '20161013170437', 'republisher': 'associate-amy-alexander@archive.org', 'imagecount': '230', 'foldoutcount': '0', 'identifier-access': 'http://archive.org/details/00ryma_0', 'identifier-ark': 'ark:/13960/t5m95558x', 'bookplateleaf': '0002', 'ocr': 'ABBYY FineReader 11.0', 'scanfee': '120', 'invoice': '1', 'curation': '[curator]associate-denise-bentley@archive.org[/curator][date]20161107154107[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20161130', 'backup_location': 'ia906208_3', 'openlibrary_edition': 'OL11445600M', 'openlibrary_work': 'OL9636674W', 'external-identifier': 'urn:oclc:record:1037356169'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef91'), 'language': 'Ukrainian', 'scanningcenter': 'alberta', 'sponsor': 'University of Alberta Libraries', 'contributor': 'Canadian Institute of Ukrainian Studies', 'date': '1999', 'subject': ['Trylʹovsʹkyĭ, Kyrylo', 'Nationalists'], 'title': 'З мого життя', 'creator': 'Tryliovsky, Kyrylo', 'isbn': '1895571308', 'collection': ['cius_books', 'ualberta_ukrainian_studies', 'university_of_alberta_libraries', 'toronto'], 'shiptracking': 'cius02', 'cat_key': '2570608', 'patron_notes': 'З мого життя (From My Life) are the memoirs of Kyrylo Tryliovsky (1864–1941), remembered chiefly as the founder of the Sich Society in the Hutsul and Pokutia regions of western Ukraine, before the First World War.', 'publisher': 'Edmonton : Kanadsʹkyĭ in-t ukraïnsʹkykh studiĭ ; Kyïv : Vyd-vo TAKSON', 'description': ['"Literaturno-khudoz͡hni͡e vydanni͡a"--Colophon', '43'], 'mediatype': 'texts', 'repub_state': '4', 'page-progression': 'lr', 'publicdate': '2016-10-03 19:46:47', 'updatedate': '2016-10-03 20:45:51', 'updater': 'associate-aaron-campbell@archive.org', 'identifier': '00tryl_0', 'uploader': 'associate-aaron-campbell@archive.org', 'addeddate': '2016-10-03 20:45:54', 'scanner': 'scribe1.alberta.archive.org', 'notes': 'No table-of-contents pages found.', 'repub_seconds': '305', 'ppi': '500', 'camera': 'Canon EOS 5D Mark II', 'operator': 'associate-tanya-ulmer@archive.org', 'scandate': '20161013162415', 'republisher': 'associate-mark-turnbull@archive.org', 'imagecount': '304', 'foldoutcount': '0', 'identifier-access': 'http://archive.org/details/00tryl_0', 'identifier-ark': 'ark:/13960/t11p31f4k', 'bookplateleaf': '0003', 'ocr': 'ABBYY FineReader 11.0', 'scanfee': '120', 'invoice': '1', 'sponsordate': '20161130', 'backup_location': 'ia906208_3', 'openlibrary_edition': 'OL6872411M', 'openlibrary_work': 'OL7825234W', 'external-identifier': 'urn:oclc:record:1037391673'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef92'), 'title': 'Catalogus der handschriften ..', 'volume': 'v.04 pt.01', 'creator': 'Amsterdam. Universiteit. Bibliotheek', 'subject': 'Manuscripts -- Bibliography', 'description': ['Schenking-Diederichs. Nederlandsche afdeeling. Bewerkt door J. Hellendoorn. 1899.- II. De handschriften der Stedelijke bibliotheek met de latere aanwinsten. Bewerkt door M.B. Mendes da Costa. Vooraf eenige mededeelingen over de geschiedenis van de bibliotheek en hare handschriftenverzameling, door den bibliothecaris C.P. Burger, jr. 1902.- III. Schenking-Diederichs. Fransche afdeeling. Bewerkt door J. Hollendoorn. 1903.- IV. Brieven. 1919.- V. Schenking-Diederichs. Kleinere afdeelingen (Engeland en Noord-American, Scandinavische landen, Rusland en Polen) Bewerkt door T.P. Sevensma. 1913.- VI. Schenking-Diederichs. Kleinere afdeelingen (Italië, Spanje, Portugal, Hongarije, Turkije, Griekenland, Indië, enz.) Bewerkt door Bertha M.v.d. Stempel. 1917.- VII. De handschriften, krachtens buikleencontract in de Universitetsbibliotheek berustende. 1e gedeelte: De handschriften van de Remonstrantsche kerk beschreven door M.B. Mendes da Costa. De handscriften van het Evangelisch-luthersche seminarium en van de Vereenigde Doopsgezinde gemeente, beschreven door J. Berg. 1923', '26'], 'publisher': 'Amsterdam', 'date': '1899-1923', 'language': 'dut', 'sponsor': 'University of Toronto', 'contributor': 'Robarts - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['robarts', 'toronto'], 'call_number': 'AFE-3600', 'updatedate': '2008-11-11 15:23:36', 'updater': 'Marlete Kurten', 'identifier': '01catalogusderha04amstuoft', 'uploader': 'marlete@archive.org', 'addeddate': '2008-11-11 15:24:07', 'publicdate': '2008-11-11 15:24:13', 'ppi': '400', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-jake-keating@archive.org', 'scanner': 'scribe16.toronto.archive.org', 'missingpages': None, 'scandate': '20081112193309', 'imagecount': '292', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/01catalogusderha04amstuoft', 'identifier-ark': 'ark:/13960/t1gh9rv7p', 'scanfactors': '5', 'repub_state': '4', 'curation': '[curator]julie@archive.org[/curator][date]20081205012434[/date][state]approved[/state]', 'sponsordate': '20081130', 'backup_location': 'ia903602_19', 'openlibrary_edition': 'OL23262373M', 'openlibrary_work': 'OL1299493W', 'external-identifier': 'urn:oclc:record:1037385485'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef93'), 'identifier': '01generalin00ontauoft', 'title': 'General index to the Journals and Sessional papers of the Legislative Assembly, Ontario, 1901 to 1912 : also index to the Divisions in House and lists of appendixes to journal for same period', 'creator': ['Ontario. Legislative Assembly', 'Ontario. Legislative Assembly. Sessional papers ... of the Province of Ontario', 'Ontario. Legislative Assembly. Journals of the Legislative Assembly of the Province of Ontario', 'Sydere, Arthur H. (Arthur Henry), 1841-1926'], 'mediatype': 'texts', 'description': '45', 'date': '1901-1912', 'year': '1901', 'subject': ['Legislative journals -- Ontario Indexes', 'Ontario -- Politics and government'], 'publicdate': '2007-07-26 18:54:26', 'addeddate': '2007-07-26 18:54:16', 'uploader': 'liz@archive.org', 'updater': ['scanner-liz-ridolfo', 'gabe@archive.org'], 'updatedate': ['2007-07-26 18:54:13', '2007-08-14 17:00:58'], 'contributor': 'Legislative Assembly of Ontario', 'publisher': 'Toronto : W. Briggs', 'language': 'eng', 'sponsor': 'Legislative Assembly of Ontario', 'scanningcenter': 'uoft', 'call_number': '000029806160', 'repub_state': '4', 'imagecount': '520', 'ppi': '500', 'lcamid': '327166', 'rcamid': '331217', 'camera': '1Ds', 'operator': 'scanner-hari-alluri@archive.org', 'scanner': 'ias7', 'scandate': '20070727172356', 'identifier-access': 'http://www.archive.org/details/01generalin00ontauoft', 'identifier-ark': 'ark:/13960/t8sb40m62', 'curatestate': 'approved', 'sponsordate': '20080531', 'possible-copyright-status': '&copy; Legislative Assembly of Ontario. May be reproduced for non-commercial purposes.', 'curation': '[curator]sharda@archive.org[/curator][date]20091125231546[/date][state]approved[/state]', 'filesxml': 'Wed Mar 17 3:44:52 UTC 2010', 'collection': ['ontla', 'toronto', 'governmentpublications'], 'foldoutcount': '0', 'backup_location': 'ia903601_5', 'openlibrary_edition': 'OL7043731M', 'openlibrary_work': 'OL3156143W', 'external-identifier': 'urn:oclc:record:1037380256'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef94'), 'title': 'Hydrologic data, 1964', 'volume': 'no.130:64 v.2', 'creator': ['California. Dept. of Water Resources', 'Warne, William E', 'Mullnix, Lawrence A', 'Angel, Jacob', 'Werner, Carla'], 'subject': ['Hydrology', 'Water-supply'], 'description': ['7 folded maps (some col.), 1 folded chart inserted', '"William E. Warne, Director, Department of Water Resources."', '"This report was prepared ... by Carl A. Werner, Lawrence A. Mullnix, Jacob Angel"--P. ix', '"May 1966."'], 'publisher': '[Sacramento, Calif.] : The Department', 'date': '1966', 'language': 'eng', 'page-progression': 'lr', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'sponsor': 'Kahle/Austin Foundation and Omidyar Network', 'contributor': 'University of California Libraries', 'scanningcenter': 'rich', 'mediatype': 'texts', 'call_number': 'TC824.C2 A2 no.130:64 v.2', 'collection-library': 'ucd', 'identifier-bib': 'DVXL-002999036', 'updatedate': '2009-04-21 15:06:36', 'updater': 'sf-loaders@archive.org', 'identifier': '01hydrologicdata19130642calirich', 'uploader': 'sf-loaders@archive.org', 'addeddate': '2009-04-21 15:06:38', 'publicdate': '2009-04-21 15:06:48', 'ppi': '400', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-kevin-narine@archive.org', 'scanner': 'scribe3.rich.archive.org', 'missingpages': None, 'scandate': '20090424195812', 'imagecount': '448', 'foldoutcount': '9', 'identifier-access': 'http://www.archive.org/details/01hydrologicdata19130642calirich', 'identifier-ark': 'ark:/13960/t9k365j3j', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '7', 'repub_state': '4', 'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]', 'collection': ['cawaterres', 'ucdavis', 'americana'], 'backup_location': 'ia903603_0', 'openlibrary_edition': 'OL25391116M', 'openlibrary_work': 'OL16722313W', 'external-identifier': 'urn:oclc:record:1037399464'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef95'), 'identifier': '01monprevwagenonconrich', 'title': 'Montana prevailing wage rates : nonconstruction services rates effective June 30, 2001', 'creator': 'Montana. Job Service Division', 'mediatype': 'texts', 'date': '2001', 'year': '2001', 'subject': ['Service industries workers', 'Wages'], 'publicdate': '2008-11-18 18:44:12', 'addeddate': '2008-11-18 18:44:01', 'uploader': 'markg@archive.org', 'updater': ['MarkGraves', 'Andy Wilcoxon'], 'updatedate': ['2008-11-18 18:43:58', '2009-06-24 21:15:55'], 'contributor': 'Montana State Library', 'publisher': 'Helena, MT : The Division', 'language': 'eng', 'sponsor': 'Montana State Library', 'scanningcenter': 'rich', 'identifier-bib': '30864001558595', 'ppi': '300', 'camera': 'Canon 5D', 'operator': 'scanner-francis-ong@archive.org', 'scanner': 'scribe8.rich.archive.org', 'scandate': '20081119150421', 'imagecount': '64', 'identifier-access': 'http://www.archive.org/details/01monprevwagenonconrich', 'identifier-ark': 'ark:/13960/t3rv0tr96', 'scanfactors': '3', 'curation': '[curator]markg@archive.org[/curator][date]20081121193149[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20081130', 'volume': '2001', 'collection': ['MontanaStateLibrary', 'americana'], 'call_number': '331.21', 'oclc-id': '47106465', 'biblevel': 'monograph', 'description': 'Cover title', 'foldoutcount': '0', 'repub_state': '4', 'backup_location': 'ia903602_19', 'openlibrary_edition': 'OL22796086M', 'openlibrary_work': 'OL13683703W', 'external-identifier': 'urn:oclc:record:1037395250'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef96'), 'title': 'Philosophia militans : gegen Klerikalismus und Naturalismus', 'creator': 'Paulsen, Friedrich, 1846-1908', 'subject': ['Naturalism', 'Philosophy and religion', 'Philosophy, German', 'Philosophy, Modern'], 'description': '24', 'publisher': 'Berlin : Reuther & Reichard', 'date': '1901', 'language': 'ger', 'copyright-evidence-operator': 'andrea@archive.org', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'copyright-region': 'US', 'copyright-evidence': 'Evidence reported by andrea@archive.org for item 01philosophiamilit00pauluoft on June 12, 2008: no visible notice of copyright; stated date is 1901.', 'copyright-evidence-date': '20080612144232', 'sponsor': 'MSN', 'contributor': 'OISE - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['oiseut', 'toronto'], 'call_number': 'AXU-2235', 'repub_state': '-1', 'updatedate': '2008-06-12 14:42:36', 'updater': 'andrea@archive.org', 'identifier': '01philosophiamilit00pauluoft', 'uploader': 'andrea@archive.org', 'addeddate': '2008-06-12 14:42:38', 'publicdate': '2008-06-12 14:43:02', 'ppi': '500', 'lcamid': '342124', 'rcamid': '327166', 'camera': '1Ds', 'operator': 'scanner-terry-haryett@archive.org', 'scanner': 'iasw2', 'missingpages': None, 'scandate': '20080618155814', 'imagecount': '210', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/01philosophiamilit00pauluoft', 'identifier-ark': 'ark:/13960/t9m32xw3x', 'scanfactors': '0', 'curation': '[curator]sharda@archive.org[/curator][date]20080620000515[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20080630', 'backup_location': 'ia903602_2', 'openlibrary_edition': 'OL23262420M', 'openlibrary_work': 'OL1534544W', 'external-identifier': 'urn:oclc:record:697603602'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef97'), 'title': 'Polybiblion; revue bibliographique universelle', 'volume': 'v.137 n.01', 'creator': 'Société bibliographique, Paris', 'subject': ['Bibliography -- Periodicals', 'Books -- Reviews', 'French literature -- Bibliography Periodicals'], 'description': ['Published by the Société bibliographique', 'Absorbed the Bulletin critique de littérature in 1909', '26'], 'publisher': 'Paris', 'language': 'fre', 'sponsor': 'University of Toronto', 'contributor': 'Robarts - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['robarts', 'toronto'], 'call_number': 'ABC 8014', 'updatedate': '2008-10-09 20:36:44', 'updater': 'Marlete Kurten', 'identifier': '01polybiblionre137sociuoft', 'uploader': 'marlete@archive.org', 'addeddate': '2008-10-09 20:34:50', 'publicdate': '2008-10-09 20:34:58', 'ppi': '400', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-jake-keating@archive.org', 'scanner': 'scribe12.toronto.archive.org', 'missingpages': None, 'scandate': '20081014175837', 'imagecount': '92', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/01polybiblionre137sociuoft', 'identifier-ark': 'ark:/13960/t9m332r8k', 'scanfactors': '0', 'repub_state': '4', 'curation': '[curator]julie@archive.org[/curator][date]20081109[/date][state]approved[/state][comment][/comment]', 'sponsordate': '20081031', 'backup_location': 'ia903602_15', 'openlibrary_edition': 'OL19359040M', 'openlibrary_work': 'OL16891258W', 'external-identifier': 'urn:oclc:record:1037355469'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef98'), 'title': 'Die Erdkunde im Verhältniss zur Natur und zur Geschichte des Menschen; oder, Allgemeine vergleichende Geographie als sichere Grundlage des Studiums und Unterrichts in physikalischen und historischen Wissenschaften', 'volume': '01 pt.02', 'creator': 'Ritter, Carl, 1779-1859', 'subject': ['Physical geography -- Asia', 'Asia -- Description and travel'], 'description': ['Vol. 1. Afrika.- Vol. 2. Der Norden und Nord-Osten von Hoch-Asien.- Vol. 3. Der Nord-Osten und der Süden von Hoch-Asien.- Vol. 4. Der Süd-Osten von Hoch-Asien; dessen Wassersysteme und Gliederungen gegen Osten und Süden.- Vol. 5-6. Die indische Welt.- Vol. 7. West-Asien. Uebergang von Ost- nach West-Asien.- Vol. 8-9. West-Asien. Iranische Welt.- Vol. 10-11. Das Stufenland des Euphrat- und Tigrissystems.- Vol. 12-13. Die Halbinsel Arabien. Namen- und Sach-Verzeichniss [v. 12-13] bearb. von G.Fr.H. Müller.- Vol. 14. Die Sinai-Halbinsel.- Vol. 15 pt. 1-2. Palästina und Syrien. Namen- und Sach-Verzeichniss [v. 14-15] bearb. von G.Fr.H. Müller.- Vol. 16 pt. 1. Palästina und Syrien: Judäa, Samaria, Galiläa.- Vol. 17. pt. 1-2. Syrien. 1. Phönicien, Libanon und gebirgiges Nord-Syrien. 2. Das Stromsystem des Orontes und das flache Nord-Syrien mit der Amanuskette. Namen- und Sach-Verzeichniss [v. 16-17] bearb. von G.Fr.H. Müller.- Vol. 18-19. Klein-Asien', '26'], 'publisher': 'Berlin, G. Reimer', 'date': '1822-1849', 'language': 'ger', 'sponsor': 'University of Toronto', 'contributor': 'Robarts - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['robarts', 'toronto'], 'call_number': 'AEX-7085', 'updatedate': '2008-11-14 21:55:43', 'updater': 'Marlete Kurten', 'identifier': '02dieerdkundeimver15rittuoft', 'uploader': 'marlete@archive.org', 'addeddate': '2008-11-14 21:56:15', 'publicdate': '2008-11-14 21:56:22', 'ppi': '400', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-bruce-milne@archive.org', 'scanner': 'scribe14.toronto.archive.org', 'missingpages': None, 'scandate': '20081117221411', 'imagecount': '748', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/02dieerdkundeimver15rittuoft', 'identifier-ark': 'ark:/13960/t6154vp5q', 'scanfactors': '1', 'repub_state': '4', 'curation': '[curator]sharda@archive.org[/curator][date]20081129000608[/date][state]approved[/state]', 'sponsordate': '20081130', 'backup_location': 'ia903602_19', 'openlibrary_edition': 'OL23262444M', 'openlibrary_work': 'OL3705262W', 'external-identifier': 'urn:oclc:record:1037355995'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef99'), 'title': 'A history of Greece;', 'volume': '4 pt. 2', 'creator': 'Duruy, Victor, 1811-1894', 'description': '45 52', 'publisher': 'London, Paul', 'date': '1892', 'language': 'eng', 'page-progression': 'lr', 'sponsor': 'University of Toronto', 'contributor': 'Robarts - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['robarts', 'toronto'], 'call_number': 'AEN-9686', 'repub_state': '4', 'updatedate': '2011-01-10 21:38:35', 'updater': 'Kate Farnworth', 'identifier': '02historyofgree04duru', 'uploader': 'scanner-kate-farnworth@archive.org', 'addeddate': '2011-01-10 21:38:37', 'publicdate': '2011-01-10 21:38:40', 'scanner': 'scribe23.toronto.archive.org', 'ppi': '300', 'camera': 'Canon 5D', 'operator': 'scanner-m-turnbull@archive.org', 'scandate': '20110111193051', 'imagecount': '314', 'foldoutcount': '2', 'identifier-access': 'http://www.archive.org/details/02historyofgree04duru', 'identifier-ark': 'ark:/13960/t46q2s68t', 'bookplateleaf': '0002', 'ocr': 'ABBYY FineReader 8.0', 'curation': '[curator]sharda@archive.org[/curator][date]20110203190403[/date][state]approved[/state]', 'sponsordate': '20110131', 'scanfee': '105', 'backup_location': 'ia903608_12', 'openlibrary_edition': 'OL24773151M', 'openlibrary_work': 'OL15864488W', 'external-identifier': 'urn:oclc:record:698288050'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef9a'), 'title': 'Hydrologic data, 1964. Appendix C: Ground water measurements', 'volume': 'no.130:64 v.2 Appx. C', 'creator': ['California. Dept. of Water Resources', 'Warne, William E'], 'subject': ['Hydrology', 'Water-supply', 'Groundwater'], 'description': ['10 folded maps in pocket', '"September 1965."', '"William E. Warne, Director, Department of Water Resources."'], 'publisher': '[Sacramento, Calif.] : The Department', 'date': '1965', 'language': 'eng', 'page-progression': 'lr', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'sponsor': 'Kahle/Austin Foundation and Omidyar Network', 'contributor': 'University of California Libraries', 'scanningcenter': 'rich', 'mediatype': 'texts', 'call_number': 'TC824.C2 A2 no.130:64 v.2 Appx. C', 'collection-library': 'ucd', 'identifier-bib': 'DVXL-002999037', 'updatedate': '2009-04-21 15:09:17', 'updater': 'sf-loaders@archive.org', 'identifier': '02hydrologicdata19130642calirich', 'uploader': 'sf-loaders@archive.org', 'addeddate': '2009-04-21 15:09:19', 'publicdate': '2009-04-21 15:09:30', 'ppi': '400', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-sokpheap-meas@archive.org', 'scanner': 'scribe9.rich.archive.org', 'missingpages': None, 'scandate': '20090423184438', 'imagecount': '232', 'foldoutcount': '11', 'identifier-access': 'http://www.archive.org/details/02hydrologicdata19130642calirich', 'identifier-ark': 'ark:/13960/t59c7b05z', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '7', 'repub_state': '4', 'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]', 'collection': ['cawaterres', 'ucdavis', 'americana'], 'backup_location': 'ia903603_0', 'openlibrary_edition': 'OL23335196M', 'openlibrary_work': 'OL5337985W', 'external-identifier': 'urn:oclc:record:1037357646'}
# {'_id': ObjectId('5fa1a22c8016ac27739bef9b'), 'identifier': '02lastmohicans00cooprich', 'uploader': 'scanner-ian-white@archive.org', 'addeddate': '2006-09-12 23:44:42', 'title': 'The last of the Mohicans : a narrative of 1757', 'creator': ['Cooper, James Fenimore, 1789-1851', 'Darley, Felix Octavius Carr, 1822-1888'], 'subject': ['Mohegan Indians', 'United States -- History French and Indian War, 1755-1763 Fiction'], 'date': '1902?', 'publisher': 'New York : D. Appleton', 'language': 'eng', 'copyright-evidence-operator': 'scanner-ian-white', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'copyright-region': 'US', 'copyright-evidence': 'Evidence reported by scanner-ian-white for item 02lastmohicans00cooprich on Sep 12, 2006; no visible notice of copyright and date found; exact publication date unknown; not published by the US government; a copyright renewal record could not be found.', 'copyright-evidence-date': '2006-09-12 23:47:15', 'copyright-comment': None, 'call_number': 'ucb:GLAD-84237627', 'scanningcenter': 'rich', 'sponsor': 'MSN', 'mediatype': 'texts', 'contributor': 'University of California Libraries', 'updatedate': '2006-09-12 23:44:45', 'updater': 'scanner-ian-white', 'imagecount': '462', 'ppi': '500', 'operator': 'scanner-andy-wilcoxon@archive.org', 'scanner': 'rich1', 'scandate': '20060913203955', 'identifier-access': 'http://www.archive.org/details/02lastmohicans00cooprich', 'identifier-ark': 'ark:/13960/t51g0j97b', 'collection-library': 'ucb', 'identifier-bib': 'GLAD-84237627', 'publicdate': '2006-09-14 01:52:14', 'curation': '[curator]julie@archive.org[/curator][date]20060922033412[/date][state]approved[/state]', 'sponsordate': '20060930', 'lcamid': '332127', 'rcamid': '332513', 'camera': '1Ds', 'filesxml': 'Wed Mar 17 3:44:52 UTC 2010', 'collection': ['cdl', 'americana'], 'foldoutcount': '0', 'repub_state': '4', 'backup_location': 'ia903600_21', 'openlibrary_edition': 'OL7091179M', 'openlibrary_work': 'OL77958W', 'external-identifier': 'urn:oclc:record:1037355148'}
# {'_id': ObjectId('5fa1a5b78016ac27739bf756'), 'title': '0 2.°', 'creator': 'Freitas, Jordão Apollinario de', 'subject': 'Santarem, Manuel Francisco de Barros, Visconde de, 1791-1856', 'description': ['Includes bibliographical references', '52'], 'publisher': 'Lisboa : Officina typographica', 'date': '1909', 'language': 'por', 'page-progression': 'lr', 'sponsor': 'University of Toronto', 'contributor': 'Robarts - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['robarts', 'toronto'], 'call_number': 'ADT-5290', 'repub_state': '4', 'updatedate': '2010-12-07 16:36:31', 'updater': 'lexw@archive.org', 'identifier': '02viscondedesant00frei', 'uploader': 'lexw@archive.org', 'addeddate': '2010-12-07 16:36:33', 'publicdate': '2010-12-07 16:36:38', 'scanner': 'scribe22.toronto.archive.org', 'ppi': '500', 'camera': 'Canon 5D', 'operator': 'scanner-gabriel-areay@archive.org', 'scandate': '20101209012215', 'imagecount': '220', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/02viscondedesant00frei', 'identifier-ark': 'ark:/13960/t9t15t434', 'bookplateleaf': '0002', 'ocr': 'ABBYY FineReader 8.0', 'curation': '[curator]sharda@archive.org[/curator][date]20101210205314[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20101231', 'backup_location': 'ia903607_26', 'openlibrary_edition': 'OL24518541M', 'openlibrary_work': 'OL15566031W', 'external-identifier': 'urn:oclc:record:1037380004'}
# {'_id': ObjectId('5fa1a5b78016ac27739bf757'), 'title': 'Annual report', 'volume': '1903-04', 'creator': 'Chicago Historical Society', 'description': '26', 'publisher': 'Chicago', 'date': '1902-20', 'language': 'eng', 'copyright-evidence-operator': 'liz ridolfo', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'copyright-region': 'US', 'copyright-evidence': 'Evidence reported by liz ridolfo for item 0304annualreport00chicuoft on February 28, 2008: no visible notice of copyright; stated date is 1903.', 'copyright-evidence-date': '20080228235252', 'sponsor': 'MSN', 'contributor': 'Robarts - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['robarts', 'toronto'], 'call_number': 'AHE-1796', 'updatedate': '2008-02-28 23:52:59', 'updater': 'liz ridolfo', 'identifier': '0304annualreport00chicuoft', 'uploader': 'liz@archive.org', 'addeddate': '2008-02-28 23:49:51', 'publicdate': '2008-02-28 23:53:05', 'imagecount': '72', 'ppi': '400', 'camera': 'Canon 5D', 'operator': 'michaelg@archive.org', 'scanner': 'scribe21', 'scandate': '20080229031803', 'identifier-access': 'http://www.archive.org/details/0304annualreport00chicuoft', 'identifier-ark': 'ark:/13960/t4dn44t8z', 'bookplateleaf': '0004', 'lcamid': None, 'rcamid': None, 'missingpages': None, 'foldoutcount': '0', 'curation': '[curator]julie@archive.org[/curator][date]20080319152038[/date][state]approved[/state]', 'sponsordate': '20080229', 'filesxml': ['Mon Aug 17 21:09:47 UTC 2009', 'Fri Aug 28 2:20:32 UTC 2015', 'Fri Aug 28 2:27:29 UTC 2015'], 'ocr': 'ABBYY FineReader 8.0', 'repub_state': '4', 'backup_location': 'ia903601_25', 'openlibrary_edition': 'OL22796100M', 'openlibrary_work': 'OL13134271W', 'external-identifier': 'urn:oclc:record:848313051'}
# {'_id': ObjectId('5fa1a5b78016ac27739bf758'), 'title': 'Chosn pulgyo tongsa', 'volume': '3', 'creator': 'Yi, Nng-hwa, 1865-1945', 'subject': 'Buddhism', 'description': ['Text in Hanmun (Chinese characters)', '11'], 'publisher': 'Kynsng-pu : Sinmungwan,[1918]', 'date': '1918', 'language': 'kor', 'possible-copyright-status': 'Permission Granted to Digitize Item', 'sponsor': 'University of Toronto', 'contributor': 'Cheng Yu Tung East Asian Library - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['chengyutung', 'toronto'], 'call_number': 'ALY-2670', 'updatedate': '2009-02-17 18:50:16', 'updater': 'KatieLawson', 'identifier': '03chosnpulgyotongs8800uoft', 'uploader': 'katie@archive.org', 'addeddate': '2009-02-17 18:50:19', 'publicdate': '2009-02-17 18:50:23', 'ppi': '500', 'lcamid': '319253', 'rcamid': '330983', 'camera': '1Ds', 'operator': 'scanner-alicia-pryce@archive.org', 'scanner': 'iasw7.toronto.archive.org', 'missingpages': None, 'scandate': '20090224225010', 'imagecount': '1278', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/03chosnpulgyotongs8800uoft', 'identifier-ark': 'ark:/13960/t6nz8hd2k', 'ocr': 'ABBYY FineReader 9.0', 'repub_state': '4', 'curation': '[curator]sharda@archive.org[/curator][date]20090304200925[/date][state]approved[/state]', 'sponsordate': '20090228', 'page-progression': 'rl', 'backup_location': 'ia903602_28', 'openlibrary_edition': 'OL23262456M', 'openlibrary_work': 'OL13786627W', 'external-identifier': 'urn:oclc:record:1037380550'}
# {'_id': ObjectId('5fa1a5b78016ac27739bf759'), 'title': 'Hydrologic data, 1964. Appendix D: Surface water quality : Appendix E: Ground water quality', 'volume': 'no.130:64 v.2 Appx. D-E', 'creator': ['California. Dept. of Water Resources', 'Warne, William E'], 'subject': ['Hydrology', 'Water-supply', 'Groundwater'], 'description': ['"June 1966."', '"William E. Warne, Director, Department of Water Resources."'], 'publisher': '[Sacramento, Calif.] : The Department', 'date': '1966', 'language': 'eng', 'page-progression': 'lr', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'sponsor': 'Kahle/Austin Foundation and Omidyar Network', 'contributor': 'University of California Libraries', 'scanningcenter': 'rich', 'mediatype': 'texts', 'call_number': 'TC824.C2 A2 no.130:64 v.2 Appx. D-E', 'collection-library': 'ucd', 'identifier-bib': 'DVXL-002999038', 'updatedate': '2009-04-21 15:10:30', 'updater': 'sf-loaders@archive.org', 'identifier': '03hydrologicdata19130642calirich', 'uploader': 'sf-loaders@archive.org', 'addeddate': '2009-04-21 15:10:32', 'publicdate': '2009-04-21 15:10:42', 'ppi': '300', 'lcamid': '315160', 'rcamid': '324758', 'camera': '1Ds', 'operator': 'scanner-jennifer-mansfield@archive.org', 'scanner': 'richw1.rich.archive.org', 'missingpages': None, 'scandate': '20090423185522', 'imagecount': '248', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/03hydrologicdata19130642calirich', 'identifier-ark': 'ark:/13960/t75t4104d', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '0', 'repub_state': '4', 'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]', 'collection': ['cawaterres', 'ucdavis', 'americana'], 'backup_location': 'ia903603_0', 'openlibrary_edition': 'OL23335197M', 'openlibrary_work': 'OL5337985W', 'external-identifier': 'urn:oclc:record:1037356842'}
# {'_id': ObjectId('5fa1a5b78016ac27739bf75a'), 'identifier': '04representmen00emerrich', 'call_number': 'ucb:GLAD-84064315', 'scanningcenter': 'rich', 'sponsor': 'MSN', 'mediatype': 'texts', 'contributor': 'University of California Libraries', 'updatedate': '2006-09-13 16:15:55', 'updater': 'scanner-ian-white', 'title': 'Representative men', 'creator': 'Emerson, Ralph Waldo, 1803-1882', 'date': '1904', 'publisher': 'London, J.M. Dent', 'language': 'eng', 'copyright-evidence-operator': 'scanner-ian-white', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'copyright-region': 'US', 'copyright-evidence': 'Evidence reported by scanner-ian-white for item 04representmen00emerrich on Sep 13, 2006; no visible notice of copyright and date found; stated date is 1904; not published by the US government; Have not checked for notice of renewal in the Copyright renewal records.', 'copyright-evidence-date': '2006-09-13 16:16:35', 'imagecount': '256', 'ppi': '600', 'operator': 'scanner-adrian-wiemhoff@archive.org', 'scanner': 'rich4', 'scandate': '20060914063712', 'identifier-access': 'http://www.archive.org/details/04representmen00emerrich', 'identifier-ark': 'ark:/13960/t6b27q792', 'collection-library': 'ucb', 'identifier-bib': 'GLAD-84064315', 'publicdate': '2006-09-14 04:31:00', 'curation': '[curator]julie@archive.org[/curator][date]20061006020944[/date][state]approved[/state]', 'sponsordate': '20060930', 'lcamid': '318500', 'rcamid': '319916', 'camera': '1Ds', 'filesxml': 'Wed Mar 17 3:44:52 UTC 2010', 'collection': ['cdl', 'americana'], 'foldoutcount': '0', 'repub_state': '4', 'backup_location': 'ia903600_21', 'openlibrary_edition': 'OL7229334M', 'openlibrary_work': 'OL62248W', 'external-identifier': 'urn:oclc:record:1037397093', 'addeddate': '2006-09-14 04:31:00'}
# {'_id': ObjectId('5fa1a5b78016ac27739bf75b'), 'title': 'Hydrologic data, 1964', 'volume': 'no.130:64 v.3', 'creator': ['California. Dept. of Water Resources', 'Warne, William E', 'Peterson, Glenn R'], 'subject': ['Hydrology', 'Water-supply'], 'description': ['5 folded maps inserted', '"June 1966."', '"William E. Warne, Director, Department of Water Resources."', '"Activities covered by this report were under the supervision of Glenn R. Peterson"--P. ix', 'Includes appendixes'], 'publisher': '[Sacramento, Calif.] : The Department', 'date': '1966', 'language': 'eng', 'page-progression': 'lr', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'sponsor': 'Kahle/Austin Foundation and Omidyar Network', 'contributor': 'University of California Libraries', 'scanningcenter': 'rich', 'mediatype': 'texts', 'call_number': 'TC824.C2 A2 no.130:64 v.3', 'collection-library': 'ucd', 'identifier-bib': 'DVXL-002999039', 'updatedate': '2009-04-21 15:12:06', 'updater': 'sf-loaders@archive.org', 'identifier': '04ydrologicdata19130643calirich', 'uploader': 'sf-loaders@archive.org', 'addeddate': '2009-04-21 15:12:08', 'publicdate': '2009-04-21 15:12:11', 'ppi': '400', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-kevin-narine@archive.org', 'scanner': 'scribe3.rich.archive.org', 'missingpages': None, 'scandate': '20090423201240', 'imagecount': '272', 'foldoutcount': '13', 'identifier-access': 'http://www.archive.org/details/04ydrologicdata19130643calirich', 'identifier-ark': 'ark:/13960/t3dz0mr5q', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '6', 'repub_state': '4', 'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]', 'collection': ['cawaterres', 'ucdavis', 'americana'], 'backup_location': 'ia903603_0', 'openlibrary_edition': 'OL23335198M', 'openlibrary_work': 'OL5337985W', 'external-identifier': 'urn:oclc:record:1037356127'}
# {'_id': ObjectId('5fa1a5b78016ac27739bf75c'), 'title': 'Hydrologic data, 1964', 'volume': 'no.130:64 v.4', 'creator': ['California. Dept. of Water Resources', 'Warne, William E', 'McIntyre, Victor B', 'Chastain, Cledith L'], 'subject': ['Hydrology', 'Water-supply'], 'description': ['"Activities covered by this report were under the supervision of Cledith L. Chastain, Victor B. McIntyre"--P. xi', 'Includes appendixes', '2 folded maps in pocket', '"December 1965."', '"William E. Warne, Director, Department of Water Resources."', '11 folded maps (some col.), 6 charts inserted'], 'publisher': '[Sacramento, Calif.] : The Department', 'date': '1965', 'language': 'eng', 'page-progression': 'lr', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'sponsor': 'Kahle/Austin Foundation and Omidyar Network', 'contributor': 'University of California Libraries', 'scanningcenter': 'rich', 'mediatype': 'texts', 'call_number': 'TC824.C2 A2 no.130:64 v.4', 'collection-library': 'ucd', 'identifier-bib': 'DVXL-002999040', 'updatedate': '2009-04-21 15:13:37', 'updater': 'sf-loaders@archive.org', 'identifier': '05hydrologicdata19130644calirich', 'uploader': 'sf-loaders@archive.org', 'addeddate': '2009-04-21 15:13:39', 'publicdate': '2009-04-21 15:13:47', 'ppi': '300', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-jim-post@archive.org', 'scanner': 'scribe8.rich.archive.org', 'missingpages': None, 'scandate': '20090424203945', 'imagecount': '496', 'foldoutcount': '23', 'identifier-access': 'http://www.archive.org/details/05hydrologicdata19130644calirich', 'identifier-ark': 'ark:/13960/t7cr66f85', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '17', 'repub_state': '4', 'curation': '[curator]paul.n@archive.org[/curator][date]20091201181909[/date][state]approved[/state][comment]199[/comment]', 'collection': ['cawaterres', 'ucdavis', 'americana'], 'backup_location': 'ia903603_0', 'openlibrary_edition': 'OL23335199M', 'openlibrary_work': 'OL5337985W', 'external-identifier': 'urn:oclc:record:1037358129'}
# ...
# {'_id': ObjectId('5fa1a5b78016ac27739bfb22'), 'title': "Morang's modern phonic primer", 'volume': '1', 'creator': 'Dearness, John, b. 1852', 'subject': 'Reading', 'description': ['Part 2 by John Dearness and Sidney Silcox', 'Title pages of part 2 missing'], 'publisher': 'Toronto : Morang & Co.', 'date': '1904', 'language': 'eng', 'page-progression': 'lr', 'sponsor': 'Ontario Council of University Libraries and Member Libraries', 'contributor': 'The University of Western Ontario, Western Archives', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['universitywesterno', 'toronto'], 'call_number': 'LT1001.421.5.M645 1904', 'updatedate': '2009-05-29 18:40:17', 'updater': 'KatieLawson', 'identifier': '1904morangsmoder01dearuoft', 'uploader': 'katie@archive.org', 'addeddate': '2009-05-29 18:40:19', 'publicdate': '2009-05-29 18:40:51', 'ppi': '400', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-carrie-lounsbury@archive.org', 'scanner': 'scribe12.toronto.archive.org', 'missingpages': None, 'scandate': '20090529221126', 'imagecount': '72', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/1904morangsmoder01dearuoft', 'identifier-ark': 'ark:/13960/t4jm2pd2f', 'ocr': 'ABBYY FineReader 8.0', 'repub_state': '4', 'sponsordate': '20090531', 'curation': '[curator]andrea@archive.org[/curator][date]20091204200209[/date][state]approved[/state]', 'backup_location': 'ia903603_6', 'openlibrary_edition': 'OL23335255M', 'openlibrary_work': 'OL16724659W', 'external-identifier': 'urn:oclc:record:676748185'}
# {'_id': ObjectId('5fa1a5b78016ac27739bfb23'), 'title': 'Niagara in summer and winter', 'creator': 'Jordan, J. Murray', 'description': ['The dates for each issue have been estimated', "Stamp on back inside paper cover of 1905 issue: For sale only at Tugby's 5c. and 10c. Store Niagara Falls, N. Y", 'Inscription on back inside paper cover of 1905 issue: Decoration Day, 1905 from Ada'], 'publisher': '[Philadelphia, PA] : [J. Murray Jordan]', 'date': '[19--?]-', 'language': 'eng', 'page-progression': 'lr', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'sponsor': 'Brock University', 'contributor': 'Brock University', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'call_number': 'B1181695', 'updatedate': '2009-03-17 21:38:49', 'updater': 'liz ridolfo', 'identifier': '1904niagarainsum00jorduoft', 'uploader': 'liz@archive.org', 'addeddate': '2009-03-17 21:38:51', 'publicdate': '2009-03-17 21:38:56', 'ppi': '300', 'lcamid': '330983', 'rcamid': '318502', 'camera': '1Ds', 'operator': 'scanner-gabriel-areay@archive.org', 'scanner': 'iasw3.toronto.archive.org', 'missingpages': None, 'scandate': '20090330235656', 'imagecount': '72', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/1904niagarainsum00jorduoft', 'identifier-ark': 'ark:/13960/t9h42359w', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '0', 'repub_state': '4', 'curation': '[curator]sharda@archive.org[/curator][date]20090331171619[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20090331', 'collection': ['BrockUniversity', 'toronto'], 'filesxml': 'Fri Aug 28 2:31:42 UTC 2015', 'backup_location': 'ia903602_32', 'openlibrary_edition': 'OL25533732M', 'openlibrary_work': 'OL16914859W', 'external-identifier': 'urn:oclc:record:1037453446'}
# {'_id': ObjectId('5fa1a5b78016ac27739bfb24'), 'title': 'Bulletin', 'creator': ['Literary and Historical Society of Quebec', 'Literary and Historical Society of Quebec. Library bulletin'], 'subject': 'Québec (Province) -- History Societies, etc', 'description': ['Title varies: 1906, Library bulletin', '26'], 'publisher': '[Quebec]', 'language': 'eng', 'copyright-evidence-operator': 'andrea@archive.org', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'copyright-region': 'US', 'copyright-evidence': 'Evidence reported by andrea@archive.org for item 1904quebechist00liteuoft on May 24, 2007: no visible notice of copyright; stated date is 1904.', 'copyright-evidence-date': '20070524183130', 'sponsor': 'MSN', 'contributor': 'Robarts - University of Toronto', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'collection': ['robarts', 'toronto'], 'call_number': 'AAU-3676', 'identifier-access': 'http://www.archive.org/details/1904quebechist00liteuoft', 'updatedate': '2007-05-24 18:31:54', 'updater': 'andrea@archive.org', 'identifier': '1904quebechist00liteuoft', 'uploader': 'andrea@archive.org', 'addeddate': '2007-05-24 18:31:56', 'publicdate': '2007-05-24 18:31:59', 'imagecount': '100', 'ppi': '500', 'lcamid': '330983', 'rcamid': '332493', 'camera': '1Ds', 'operator': 'scanner-lisa-munroe@archive.org', 'scanner': 'ias2', 'scandate': '20070526000322', 'identifier-ark': 'ark:/13960/t4qj7b054', 'bookplateleaf': '0003', 'curation': '[curator]marcus@archive.org[/curator][date]20070608180014[/date][state]approved[/state]', 'sponsordate': '20070531', 'filesxml': 'Wed Mar 17 3:47:46 UTC 2010', 'foldoutcount': '0', 'ocr': 'ABBYY FineReader 8.0', 'repub_state': '4', 'backup_location': 'ia903601_1', 'openlibrary_edition': 'OL13988434M', 'openlibrary_work': 'OL17774140W', 'external-identifier': 'urn:oclc:record:1037447955'}
# {'_id': ObjectId('5fa1a5b78016ac27739bfb25'), 'title': '... 1904 supplement to 1903 catalogue : new, rare and beautiful plants and seeds', 'volume': '1904', 'creator': ['Theodosia B. Shepherd Company', 'Henry G. Gilbert Nursery and Seed Trade Catalog Collection'], 'subject': ['Seed industry and trade Catalogs', 'Seeds Catalogs', 'Flowers Seeds Catalogs', 'Plants, Ornamental Catalogs', 'Nurseries (Horticulture) Catalogs'], 'description': 'Cover title', 'publisher': 'Ventura-by-the-Sea, Calif. : Theodosia B. Shepherd Co.', 'date': '1904', 'language': 'eng', 'page-progression': 'lr', 'sponsor': 'U.S. Department of Agriculture, National Agricultural Library', 'contributor': 'U.S. Department of Agriculture, National Agricultural Library', 'scanningcenter': 'beltsville', 'mediatype': 'texts', 'collection': ['usda-nurseryandseedcatalog', 'usdanationalagriculturallibrary', 'fedlink', 'americana', 'biodiversity'], 'shiptracking': 'SC0005a', 'call_number': 'CAT31116265', 'identifier-bib': 'CAT31116265', 'series': 'Henry G. Gilbert Nursery and Seed Trade Catalog Collection', 'unique_id': 'CAT31116265', 'nal_call_number': '62.09', 'repub_state': '4', 'updatedate': '2013-04-15 15:32:10', 'updater': 'associate-adrianna-flores', 'identifier': '1904supplementto1904theo', 'uploader': 'associate-adrianna-flores@archive.org', 'addeddate': '2013-04-15 15:32:12', 'publicdate': '2013-04-15 15:32:15', 'repub_seconds': '432790', 'ppi': '500', 'camera': 'Canon EOS 5D Mark II', 'operator': 'associate-kellen-goodwin@archive.org', 'scanner': 'scribe3.beltsville.archive.org', 'scandate': '20130417134601', 'republisher': 'associate-kellen-goodwin@archive.org', 'imagecount': '24', 'foldoutcount': '0', 'identifier-access': 'http://archive.org/details/1904supplementto1904theo', 'identifier-ark': 'ark:/13960/t8md0h39m', 'ocr': 'ABBYY FineReader 8.0', 'scanfee': '250', 'curation': '[curator]associate-caitlin-markey@archive.org[/curator][date]20130429161238[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20130430', 'rights': 'The contributing institution believes that this item is not in copyright.', 'backup_location': 'ia905609_14', 'openlibrary_edition': 'OL25518714M', 'openlibrary_work': 'OL16898265W', 'external-identifier': 'urn:oclc:record:1037433922'}
# {'_id': ObjectId('5fa1a5b78016ac27739bfb26'), 'title': "1905-'06 descriptive catalogue of rare flowers : seeds, plants, bulbs, cacti, etc", 'volume': '1906', 'creator': ['Theodosia B. Shepherd Company', 'Henry G. Gilbert Nursery and Seed Trade Catalog Collection'], 'subject': ['Seed industry and trade Catalogs', 'Seeds Catalogs', 'Flowers Seeds Catalogs', 'Plants, Ornamental Catalogs', 'Nurseries (Horticulture) Catalogs', 'Cactus Seeds Catalogs'], 'description': ['Cover title', 'Includes index'], 'publisher': 'Ventura-by-the-Sea, Calif. : Theodosia B. Shepherd Co.', 'date': '1906', 'language': 'eng', 'page-progression': 'lr', 'sponsor': 'U.S. Department of Agriculture, National Agricultural Library', 'contributor': 'U.S. Department of Agriculture, National Agricultural Library', 'scanningcenter': 'beltsville', 'mediatype': 'texts', 'collection': ['usda-nurseryandseedcatalog', 'usdanationalagriculturallibrary', 'fedlink', 'americana', 'biodiversity'], 'shiptracking': 'NC0005c', 'call_number': 'CAT31116262', 'identifier-bib': 'CAT31116262', 'series': 'Henry G. Gilbert Nursery and Seed Trade Catalog Collection', 'unique_id': 'CAT31116262', 'nal_call_number': '62.09', 'repub_state': '4', 'updatedate': '2013-04-15 19:40:13', 'updater': 'associate-adrianna-flores', 'identifier': '190506descriptiv1906theo', 'uploader': 'associate-adrianna-flores@archive.org', 'addeddate': '2013-04-15 19:40:15', 'publicdate': '2013-04-15 19:40:19', 'scanner': 'scribe3.beltsville.archive.org', 'notes': 'No table-of-contents pages found. No copyright page found.', 'repub_seconds': '618', 'ppi': '500', 'camera': 'Canon EOS 5D Mark II', 'operator': 'associate-kellen-goodwin@archive.org', 'scandate': '20130501132453', 'republisher': 'associate-adrianna-flores@archive.org', 'imagecount': '78', 'foldoutcount': '0', 'identifier-access': 'http://archive.org/details/190506descriptiv1906theo', 'identifier-ark': 'ark:/13960/t4pk1zk5z', 'ocr': 'ABBYY FineReader 8.0', 'scanfee': '150', 'curation': '[curator]associate-manuel-dennis@archive.org[/curator][date]20130514155428[/date][state]approved[/state][comment]199[/comment]', 'sponsordate': '20130531', 'rights': 'The contributing institution believes that this item is not in copyright.', 'backup_location': 'ia905609_15', 'openlibrary_edition': 'OL25522337M', 'openlibrary_work': 'OL16902370W', 'external-identifier': 'urn:oclc:record:1037460669'}
# {'_id': ObjectId('5fa1a5b78016ac27739bfb27'), 'identifier': '1905biennialreportof1906montrich', 'title': 'Biennial report of the State Board of Land Commissioners of the state of Montana to the ... Legislative Assembly', 'creator': 'Montana. State Board of Land Commissioners', 'mediatype': 'texts', 'date': '1900', 'year': '1900', 'subject': 'Public lands', 'publicdate': '2009-03-05 15:08:56', 'addeddate': '2009-03-05 15:08:52', 'uploader': 'markg@archive.org', 'updater': ['MarkGraves', 'paul nguyen'], 'updatedate': ['2009-03-05 15:08:50', '2009-06-30 22:32:10'], 'contributor': 'Montana State Library', 'publisher': 'Helena, Mont. : State Pub. Co.', 'language': 'eng', 'sponsor': 'Montana State Library', 'scanningcenter': 'rich', 'identifier-bib': '30864100483984', 'ppi': '400', 'camera': 'Canon 5D', 'operator': 'andyw@archive.org', 'scanner': 'scribe5.rich.archive.org', 'scandate': '20090326155147', 'imagecount': '54', 'foldoutcount': '8', 'identifier-access': 'http://www.archive.org/details/1905biennialreportof1906montrich', 'identifier-ark': 'ark:/13960/t1vd7634c', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '2', 'repub_state': '4', 'curation': '[curator]naruta@archive.org[/curator][date]20090406190846[/date][state]approved[/state]', 'sponsordate': '20090331', 'volume': '1905-06', 'collection': ['MontanaStateLibrary', 'americana'], 'call_number': '333.1/09786', 'oclc-id': '32591916', 'biblevel': 'serial', 'backup_location': 'ia903602_30', 'openlibrary_edition': 'OL25589919M', 'openlibrary_work': 'OL17018164W', 'external-identifier': 'urn:oclc:record:875124861'}
# {'_id': ObjectId('5fa1a5b78016ac27739bfb28'), 'title': "Cutter's guide to Niagara Falls, and adjacent points of interest. --", 'creator': 'Cutter, Charles, 1837-1912', 'publisher': '[Niagara Falls, N. Y.] : Charles Cutter', 'date': '1905', 'language': 'eng', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'sponsor': 'Brock University', 'contributor': 'Brock University', 'scanningcenter': 'uoft', 'mediatype': 'texts', 'call_number': 'B1023135', 'updatedate': '2009-03-17 01:04:42', 'updater': 'liz ridolfo', 'identifier': '1905cuttersguide00cuttuoft', 'uploader': 'liz@archive.org', 'addeddate': '2009-03-17 01:04:45', 'publicdate': '2009-03-17 01:04:48', 'ppi': '300', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'scanner-patrick-stitt@archive.org', 'scanner': 'scribe11.toronto.archive.org', 'missingpages': None, 'scandate': '20090317231052', 'imagecount': '96', 'foldoutcount': '0', 'identifier-access': 'http://www.archive.org/details/1905cuttersguide00cuttuoft', 'identifier-ark': 'ark:/13960/t7mp5cx93', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '1', 'repub_state': '4', 'curation': '[curator]naruta@archive.org[/curator][date]20090416172045[/date][state]approved[/state]', 'sponsordate': '20090331', 'collection': ['BrockUniversity', 'toronto'], 'filesxml': 'Fri Aug 28 2:31:43 UTC 2015', 'backup_location': 'ia903602_32', 'openlibrary_edition': 'OL23263443M', 'openlibrary_work': 'OL11727641W', 'external-identifier': 'urn:oclc:record:1037422247'}
# {'_id': ObjectId('5fa1a5b78016ac27739bfb29'), 'title': '[Bulletin] showing by counties the mineral productions of California for the year 1905', 'volume': 'no.42', 'creator': ['Yale, Charles G', 'California State Mining Bureau'], 'subject': 'Mines and mineral resources', 'publisher': '[Sacramento? : s.n.', 'date': '1906', 'language': 'eng', 'possible-copyright-status': 'NOT_IN_COPYRIGHT', 'sponsor': 'Kahle/Austin Foundation and Omidyar Network', 'contributor': 'University of California Libraries', 'scanningcenter': 'rich', 'mediatype': 'texts', 'call_number': 'TN24.C3 A3 no.42', 'updatedate': '2008-11-25 23:28:14', 'updater': 'ian frederick-rothwell', 'identifier': '1905etinshowingb00yalerich', 'uploader': 'ianf-r@archive.org', 'addeddate': '2008-11-25 23:28:16', 'publicdate': '2008-11-25 23:28:24', 'ppi': '300', 'lcamid': None, 'rcamid': None, 'camera': 'Canon 5D', 'operator': 'andyw@archive.org', 'scanner': 'scribe10.rich.archive.org', 'missingpages': None, 'scandate': '20081209193740', 'imagecount': '12', 'foldoutcount': '4', 'identifier-access': 'http://www.archive.org/details/1905etinshowingb00yalerich', 'identifier-ark': 'ark:/13960/t2794fs4r', 'ocr': 'ABBYY FineReader 8.0', 'scanfactors': '1', 'repub_state': '4', 'curation': '[curator]markg@archive.org[/curator][date]20081217190150[/date][state]approved[/state][comment]199[/comment]', 'collection_library': 'ucd', 'collection-library': 'ucd', 'collection': ['caminesgeo', 'ucdavis', 'americana'], 'backup_location': 'ia903602_20', 'openlibrary_edition': 'OL22803895M', 'openlibrary_work': 'OL16724663W', 'external-identifier': 'urn:oclc:record:1037461228'}

# %% [markdown]
# ## Scratch pad

# %%
test_collection = database['test']
d = {'website': 'www.carrefax.com', 'author': 'Daniel Hoadley', 'colour': 'purple'}
test_collection.insert_one(d)

# %%
g = test_collection.find({'website': 'www.carrefax.com'}, {'website': 1})
g
for x in g:
    print(x)
# Out:
# {'_id': ObjectId('5fa14d948016ac27739bef86'), 'website': 'www.carrefax.com'}
# {'_id': ObjectId('5fa14d9d8016ac27739bef87'), 'website': 'www.carrefax.com'}
